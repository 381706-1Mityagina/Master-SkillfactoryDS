# %% [markdown]
# # Угадай число
# Нужно написать программу, которая угадывает число за минимальное число попыток.
#
# ## Условия соревнования
# - Компьютер загадывает целое число от 1 до 100, и нам его нужно угадать. Под «угадать», подразумевается «написать программу, которая угадывает число».
# - Алгоритм учитывает информацию о том, больше ли случайное число или меньше нужного нам.
# - Необходимо добиться того, чтобы программа угадывала число меньше, чем за 20 попыток.

# %% [markdown]
# Импортируем библиотеку, которая нам пригодится для генерации случайных чисел. В следующих темах вы познакомитесь с ней подробнее:

# %%
import numpy as np

# %% [markdown]
# Ниже уже даны два простейших подхода к решению этой задачи. Посмотрим на них.

# %% [markdown]
# ## Подход 1: Случайное угадывание

# %% [markdown]
# Простейший способ решения: научить программу случайным образом выбирать число до тех пор, пока оно не будет угадано. Этот способ не дает хорошего результата, однако будет для нас хорошей стартовой точкой.

# %%
def random_predict(number: int = 1) -> int:
    """Просто угадываем на random, никак не используя информацию о больше или меньше.
       Функция принимает загаданное число и возвращает число попыток

    Args:
        number (int, optional): Загаданное число. Defaults to 1.

    Returns:
        int: Число попыток
    """
    count = 0

    while True:
        count += 1
        predict_number = np.random.randint(1, 101)  # предполагаемое число
        if number == predict_number:
            break  # выход из цикла если угадали

    return count

# %% [markdown]
# ## Подход 2: Угадывание с коррекцией

# %% [markdown]
# Сначала устанавливаем любое случайное число, а потом уменьшаем или увеличиваем его в зависимости от того, больше оно или меньше нужного.

# %%
def game_core_v2(number: int = 1) -> int:
    """Сначала устанавливаем любое random число, а потом уменьшаем
    или увеличиваем его в зависимости от того, больше оно или меньше нужного.
       Функция принимает загаданное число и возвращает число попыток

    Args:
        number (int, optional): Загаданное число. Defaults to 1.

    Returns:
        int: Число попыток
    """
    count = 0
    predict = np.random.randint(1, 101)

    while number != predict:
        count += 1
        if number > predict:
            predict += 1
        elif number < predict:
            predict -= 1

    return count

# %% [markdown]
# Посмотрим, как эти программы справляются с задачей.

# %% [markdown]
# ## Функция для оценки

# %% [markdown]
# Эта функция необходима, чтобы определить, за какое число попыток программа угадывает наше число.

# %%
def score_game(random_predict) -> int:
    """За какое количество попыток в среднем за 10000 подходов угадывает наш алгоритм

    Args:
        random_predict ([type]): функция угадывания

    Returns:
        int: среднее количество попыток
    """
    count_ls = []
    #np.random.seed(1)  # фиксируем сид для воспроизводимости
    random_array = np.random.randint(1, 101, size=(10000))  # загадали список чисел

    for number in random_array:
        count_ls.append(random_predict(number))

    score = int(np.mean(count_ls))
    print(f"Ваш алгоритм угадывает число в среднем за: {score} попытки")

# %% [markdown]
# ## Оценка работы алгоритмов
# Определяем, какой подход лучше.

# %%
#Run benchmarking to score effectiveness of all algorithms
print('Run benchmarking for random_predict: ', end='')
score_game(random_predict)

print('Run benchmarking for game_core_v2: ', end='')
score_game(game_core_v2)
# Out:
# Run benchmarking for random_predict: Ваш алгоритм угадывает число в среднем за: 98 попытки
# Run benchmarking for game_core_v2: Ваш алгоритм угадывает число в среднем за: 33 попытки

# %% [markdown]
# Как мы видим, две предложенные программы показывают не лучший результат.
# Теперь вы попробуете решить эту задачу и найти более обтимальный алгоритм.

# %% [markdown]
# ## Подход 3: Ваше решение

# %% [markdown]
# Напишите функцию, которая принимает на вход загаданное число и возвращает число попыток угадывания.

# %%
def game_core_v3(number: int = 1) -> int:
    """
    Args:
        number (int, optional): Загаданное число. Defaults to 1.

    Returns:
        int: Число попыток
    """
    # Ваш код начинается здесь
    
    # Для решения этой задачи используем бинарный поиск. Параметры:
    low = 1
    high = 101

    # количество попыток
    count = 0

    while low <= high:
        count+=1
        
        # Для решения этой задачи используем бинарный поиск. Принцип:
        # Определение значения элемента в середине структуры данных. Полученное значение сравнивается с ключом (загаданное число).
        # Если ключ меньше значения середины, то поиск осуществляется в первой половине элементов, иначе — во второй.
        # Поиск сводится к тому, что вновь определяется значение серединного элемента в выбранной половине и сравнивается с ключом.
        # Процесс продолжается до тех пор, пока не будет найден элемент со значением ключа или не станет пустым интервал для поиска.
        predict_number = low + (high - low) // 2
        
        if predict_number > number:
            high = predict_number
        elif predict_number < number:
            low = predict_number
        else:
            print(f"Вы угадали число! Это число = {number}, за {count} попыток")
            break #конец игры выход из цикла

    # Ваш код заканчивается здесь

    return count

# %% [markdown]
# Оценим качество вашего алгоритма:

# %%
print('Run benchmarking for game_core_v3: ', end='')
score_game(game_core_v3)
# Out:
# Run benchmarking for game_core_v3: Вы угадали число! Это число = 61, за 6 попыток
# Вы угадали число! Это число = 23, за 7 попыток
# Вы угадали число! Это число = 7, за 4 попыток
# Вы угадали число! Это число = 100, за 7 попыток
# Вы угадали число! Это число = 63, за 3 попыток
# Вы угадали число! Это число = 50, за 7 попыток
# Вы угадали число! Это число = 7, за 4 попыток
# Вы угадали число! Это число = 80, за 6 попыток
# Вы угадали число! Это число = 17, за 6 попыток
# Вы угадали число! Это число = 45, за 6 попыток
# Вы угадали число! Это число = 54, за 5 попыток
# Вы угадали число! Это число = 49, за 6 попыток
# Вы угадали число! Это число = 71, за 7 попыток
# Вы угадали число! Это число = 91, за 5 попыток
# Вы угадали число! Это число = 18, за 7 попыток
# Вы угадали число! Это число = 97, за 5 попыток
# Вы угадали число! Это число = 30, за 6 попыток
# Вы угадали число! Это число = 44, за 4 попыток
# Вы угадали число! Это число = 23, за 7 попыток
# Вы угадали число! Это число = 55, за 6 попыток
# Вы угадали число! Это число = 5, за 6 попыток
# Вы угадали число! Это число = 95, за 6 попыток
# Вы угадали число! Это число = 49, за 6 попыток
# Вы угадали число! Это число = 25, за 7 попыток
# Вы угадали число! Это число = 35, за 5 попыток
# Вы угадали число! Это число = 68, за 7 попыток
# Вы угадали число! Это число = 37, за 7 попыток
# Вы угадали число! Это число = 10, за 5 попыток
# Вы угадали число! Это число = 17, за 6 попыток
# Вы угадали число! Это число = 97, за 5 попыток
# Вы угадали число! Это число = 20, за 6 попыток
# Вы угадали число! Это число = 45, за 6 попыток
# Вы угадали число! Это число = 41, за 5 попыток
# Вы угадали число! Это число = 44, за 4 попыток
# Вы угадали число! Это число = 51, за 1 попыток
# Вы угадали число! Это число = 100, за 7 попыток
# Вы угадали число! Это число = 40, за 7 попыток
# Вы угадали число! Это число = 3, за 7 попыток
# Вы угадали число! Это число = 66, за 5 попыток
# Вы угадали число! Это число = 81, за 7 попыток
# Вы угадали число! Это число = 85, за 5 попыток
# Вы угадали число! Это число = 42, за 6 попыток
# Вы угадали число! Это число = 1, за 7 попыток
# Вы угадали число! Это число = 20, за 6 попыток
# Вы угадали число! Это число = 54, за 5 попыток
# Вы угадали число! Это число = 24, за 6 попыток
# Вы угадали число! Это число = 41, за 5 попыток
# Вы угадали число! Это число = 44, за 4 попыток
# Вы угадали число! Это число = 13, за 3 попыток
# Вы угадали число! Это число = 62, за 7 попыток
# Вы угадали число! Это число = 20, за 6 попыток
# Вы угадали число! Это число = 29, за 5 попыток
# Вы угадали число! Это число = 45, за 6 попыток
# Вы угадали число! Это число = 83, за 6 попыток
# Вы угадали число! Это число = 24, за 6 попыток
# Вы угадали число! Это число = 93, за 7 попыток
# Вы угадали число! Это число = 53, за 7 попыток
# Вы угадали число! Это число = 6, за 7 попыток
# Вы угадали число! Это число = 35, за 5 попыток
# Вы угадали число! Это число = 38, за 3 попыток
# Вы угадали число! Это число = 44, за 4 попыток
# Вы угадали число! Это число = 26, за 2 попыток
# Вы угадали число! Это число = 15, за 7 попыток
# Вы угадали число! Это число = 86, за 6 попыток
# Вы угадали число! Это число = 76, за 2 попыток
# Вы угадали число! Это число = 37, за 7 попыток
# Вы угадали число! Это число = 88, за 3 попыток
# Вы угадали число! Это число = 42, за 6 попыток
# Вы угадали число! Это число = 50, за 7 попыток
# Вы угадали число! Это число = 33, за 6 попыток
# Вы угадали число! Это число = 81, за 7 попыток
# Вы угадали число! Это число = 25, за 7 попыток
# Вы угадали число! Это число = 57, за 4 попыток
# Вы угадали число! Это число = 59, за 7 попыток
# Вы угадали число! Это число = 81, за 7 попыток
# Вы угадали число! Это число = 29, за 5 попыток
# Вы угадали число! Это число = 76, за 2 попыток
# Вы угадали число! Это число = 61, за 6 попыток
# Вы угадали число! Это число = 28, за 7 попыток
# Вы угадали число! Это число = 82, за 4 попыток
# Вы угадали число! Это число = 96, за 7 попыток
# Вы угадали число! Это число = 82, за 4 попыток
# Вы угадали число! Это число = 64, за 6 попыток
# Вы угадали число! Это число = 72, за 5 попыток
# Вы угадали число! Это число = 32, за 4 попыток
# Вы угадали число! Это число = 20, за 6 попыток
# Вы угадали число! Это число = 87, за 7 попыток
# Вы угадали число! Это число = 38, за 3 попыток
# Вы угадали число! Это число = 34, за 7 попыток
# Вы угадали число! Это число = 26, за 2 попыток
# Вы угадали число! Это число = 77, за 6 попыток
# Вы угадали число! Это число = 16, за 5 попыток
# Вы угадали число! Это число = 27, за 6 попыток
# Вы угадали число! Это число = 52, за 6 попыток
# Вы угадали число! Это число = 51, за 1 попыток
# Вы угадали число! Это число = 23, за 7 попыток
# Вы угадали число! Это число = 100, за 7 попыток
# Вы угадали число! Это число = 43, за 7 попыток
# Вы угадали число! Это число = 2, за 6 попыток
# Вы угадали число! Это число = 9, за 7 попыток
# Вы угадали число! Это число = 23, за 7 попыток
# Вы угадали число! Это число = 10, за 5 попыток
# Вы угадали число! Это число = 49, за 6 попыток
# Вы угадали число! Это число = 68, за 7 попыток
# Вы угадали число! Это число = 87, за 7 попыток
# Вы угадали число! Это число = 92, за 6 попыток
# Вы угадали число! Это число = 71, за 7 попыток
# Вы угадали число! Это число = 63, за 3 попыток
# Вы угадали число! Это число = 83, за 6 попыток
# Вы угадали число! Это число = 35, за 5 попыток
# Вы угадали число! Это число = 27, за 6 попыток
# Вы угадали число! Это число = 63, за 3 попыток
# Вы угадали число! Это число = 13, за 3 попыток
# Вы угадали число! Это число = 2, за 6 попыток
# Вы угадали число! Это число = 74, за 6 попыток
# Вы угадали число! Это число = 14, за 6 попыток
# Вы угадали число! Это число = 75, за 7 попыток
# Вы угадали число! Это число = 18, за 7 попыток
# Вы угадали число! Это число = 37, за 7 попыток
# Вы угадали число! Это число = 15, за 7 попыток
# Вы угадали число! Это число = 16, за 5 попыток
# Вы угадали число! Это число = 61, за 6 попыток
# Вы угадали число! Это число = 7, за 4 попыток
# Вы угадали число! Это число = 55, за 6 попыток
# Вы угадали число! Это число = 66, за 5 попыток
# Вы угадали число! Это число = 42, за 6 попыток
# Вы угадали число! Это число = 94, за 4 попыток
# Вы угадали число! Это число = 47, за 5 попыток
# Вы угадали число! Это число = 18, за 7 попыток
# Вы угадали число! Это число = 42, за 6 попыток
# Вы угадали число! Это число = 91, за 5 попыток
# Вы угадали число! Это число = 89, за 6 попыток
# Вы угадали число! Это число = 52, за 6 попыток
# Вы угадали число! Это число = 3, за 7 попыток
# Вы угадали число! Это число = 68, за 7 попыток
# Вы угадали число! Это число = 28, за 7 попыток
# Вы угадали число! Это число = 53, за 7 попыток
# Вы угадали число! Это число = 10, за 5 попыток
# Вы угадали число! Это число = 5, за 6 попыток
# Вы угадали число! Это число = 100, за 7 попыток
# Вы угадали число! Это число = 88, за 3 попыток
# Вы угадали число! Это число = 98, за 7 попыток
# Вы угадали число! Это число = 24, за 6 попыток
# Вы угадали число! Это число = 68, за 7 попыток
# Вы угадали число! Это число = 90, за 7 попыток
# Вы угадали число! Это число = 89, за 6 попыток
# Вы угадали число! Это число = 57, за 4 попыток
# Вы угадали число! Это число = 23, за 7 попыток
# Вы угадали число! Это число = 97, за 5 попыток
# Вы угадали число! Это число = 68, за 7 попыток
# Вы угадали число! Это число = 30, за 6 попыток
# Вы угадали число! Это число = 73, за 7 попыток
# Вы угадали число! Это число = 89, за 6 попыток
# Вы угадали число! Это число = 65, за 7 попыток
# Вы угадали число! Это число = 98, за 7 попыток
# Вы угадали число! Это число = 13, за 3 попыток
# Вы угадали число! Это число = 45, за 6 попыток
# Вы угадали число! Это число = 24, за 6 попыток
# Вы угадали число! Это число = 60, за 5 попыток
# Вы угадали число! Это число = 92, за 6 попыток
# Вы угадали число! Это число = 70, за 6 попыток
# Вы угадали число! Это число = 12, за 7 попыток
# Вы угадали число! Это число = 87, за 7 попыток
# Вы угадали число! Это число = 73, за 7 попыток
# Вы угадали число! Это число = 58, за 6 попыток
# Вы угадали число! Это число = 27, за 6 попыток
# Вы угадали число! Это число = 87, за 7 попыток
# Вы угадали число! Это число = 89, за 6 попыток
# Вы угадали число! Это число = 68, за 7 попыток
# Вы угадали число! Это число = 71, за 7 попыток
# Вы угадали число! Это число = 20, за 6 попыток
# Вы угадали число! Это число = 77, за 6 попыток
# Вы угадали число! Это число = 22, за 5 попыток
# Вы угадали число! Это число = 21, за 7 попыток
# Вы угадали число! Это число = 59, за 7 попыток
# Вы угадали число! Это число = 3, за 7 попыток
# Вы угадали число! Это число = 89, за 6 попыток
# Вы угадали число! Это число = 91, за 5 попыток
# Вы угадали число! Это число = 75, за 7 попыток
# Вы угадали число! Это число = 89, за 6 попыток
# Вы угадали число! Это число = 52, за 6 попыток
# Вы угадали число! Это число = 5, за 6 попыток
# Вы угадали число! Это число = 48, за 7 попыток
# Вы угадали число! Это число = 36, за 6 попыток
# Вы угадали число! Это число = 69, за 4 попыток
# Вы угадали число! Это число = 41, за 5 попыток
# Вы угадали число! Это число = 37, за 7 попыток
# Вы угадали число! Это число = 48, за 7 попыток
# Вы угадали число! Это число = 44, за 4 попыток
# Вы угадали число! Это число = 17, за 6 попыток
# Вы угадали число! Это число = 42, за 6 попыток
# Вы угадали число! Это число = 25, за 7 попыток
# Вы угадали число! Это число = 21, за 7 попыток
# Вы угадали число! Это число = 18, за 7 попыток
# Вы угадали число! Это число = 32, за 4 попыток
# Вы угадали число! Это число = 16, за 5 попыток
# Вы угадали число! Это число = 37, за 7 попыток
# Вы угадали число! Это число = 80, за 6 попыток
# Вы угадали число! Это число = 33, за 6 попыток
# Вы угадали число! Это число = 69, за 4 попыток
# Вы угадали число! Это число = 47, за 5 попыток
# Вы угадали число! Это число = 42, за 6 попыток
# Вы угадали число! Это число = 72, за 5 попыток
# Вы угадали число! Это число = 28, за 7 попыток
# Вы угадали число! Это число = 36, за 6 попыток
# Вы угадали число! Это число = 21, за 7 попыток
# Вы угадали число! Это число = 68, за 7 попыток
# Вы угадали число! Это число = 46, за 7 попыток
# Вы угадали число! Это число = 16, за 5 попыток
# Вы угадали число! Это число = 41, за 5 попыток
# Вы угадали число! Это число = 89, за 6 попыток
# Вы угадали число! Это число = 17, за 6 попыток
# Вы угадали число! Это число = 95, за 6 попыток
# Вы угадали число! Это число = 41, за 5 попыток
# Вы угадали число! Это число = 62, за 7 попыток
# Вы угадали число! Это число = 16, за 5 попыток
# Вы угадали число! Это число = 38, за 3 попыток
# Вы угадали число! Это число = 8, за 6 попыток
# Вы угадали число! Это число = 33, за 6 попыток
# Вы угадали число! Это число = 50, за 7 попыток
# Вы угадали число! Это число = 96, за 7 попыток
# Вы угадали число! Это число = 17, за 6 попыток
# Вы угадали число! Это число = 26, за 2 попыток
# Вы угадали число! Это число = 11, за 6 попыток
# Вы угадали число! Это число = 10, за 5 попыток
# Вы угадали число! Это число = 7, за 4 попыток
# Вы угадали число! Это число = 100, за 7 попыток
# Вы угадали число! Это число = 99, за 6 попыток
# Вы угадали число! Это число = 49, за 6 попыток
# Вы угадали число! Это число = 89, за 6 попыток
# Вы угадали число! Это число = 70, за 6 попыток
# Вы угадали число! Это число = 13, за 3 попыток
# Вы угадали число! Это число = 93, за 7 попыток
# Вы угадали число! Это число = 99, за 6 попыток
# Вы угадали число! Это число = 31, за 7 попыток
# Вы угадали число! Это число = 6, за 7 попыток
# Вы угадали число! Это число = 37, за 7 попыток
# Вы угадали число! Это число = 3, за 7 попыток
# Вы угадали число! Это число = 56, за 7 попыток
# Вы угадали число! Это число = 100, за 7 попыток
# Вы угадали число! Это число = 1, за 7 попыток
# Вы угадали число! Это число = 92, за 6 попыток
# Вы угадали число! Это число = 4, за 5 попыток
# Вы угадали число! Это число = 34, за 7 попыток
# Вы угадали число! Это число = 30, за 6 попыток
# Вы угадали число! Это число = 73, за 7 попыток
# Вы угадали число! Это число = 13, за 3 попыток
# Вы угадали число! Это число = 30, за 6 попыток
# Вы угадали число! Это число = 85, за 5 попыток
# Вы угадали число! Это число = 5, за 6 попыток
# Вы угадали число! Это число = 69, за 4 попыток
# Вы угадали число! Это число = 24, за 6 попыток
# Вы угадали число! Это число = 48, за 7 попыток
# Вы угадали число! Это число = 20, за 6 попыток
# Вы угадали число! Это число = 43, за 7 попыток
# Вы угадали число! Это число = 82, за 4 попыток
# Вы угадали число! Это число = 97, за 5 попыток
# Вы угадали число! Это число = 100, за 7 попыток
# Вы угадали число! Это число = 76, за 2 попыток
# Вы угадали число! Это число = 19, за 4 попыток
# Вы угадали число! Это число = 8, за 6 попыток
# Вы угадали число! Это число = 78, за 7 попыток
# Вы угадали число! Это число = 6, за 7 попыток
# Вы угадали число! Это число = 53, за 7 попыток
# Вы угадали число! Это число = 25, за 7 попыток
# Вы угадали число! Это число = 21, за 7 попыток
# Вы угадали число! Это число = 14, за 6 попыток
# Вы угадали число! Это число = 85, за 5 попыток
# Вы угадали число! Это число = 98, за 7 попыток
# Вы угадали число! Это число = 77, за 6 попыток
# Вы угадали число! Это число = 64, за 6 попыток
# Вы угадали число! Это число = 51, за 1 попыток
# Вы угадали число! Это число = 79, за 5 попыток
# Вы угадали число! Это число = 26, за 2 попыток
# Вы угадали число! Это число = 92, за 6 попыток
# Вы угадали число! Это число = 51, за 1 попыток
# Вы угадали число! Это число = 17, за 6 попыток
# Вы угадали число! Это число = 33, за 6 попыток
# Вы угадали число! Это число = 55, за 6 попыток
# Вы угадали число! Это число = 38, за 3 попыток
# Вы угадали число! Это число = 2, за 6 попыток
# Вы угадали число! Это число = 62, за 7 попыток
# Вы угадали число! Это число = 85, за 5 попыток
# Вы угадали число! Это число = 9, за 7 попыток
# Вы угадали число! Это число = 38, за 3 попыток
# Вы угадали число! Это число = 77, за 6 попыток
# Вы угадали число! Это число = 45, за 6 попыток
# Вы угадали число! Это число = 88, за 3 попыток
# Вы угадали число! Это число = 2, за 6 попыток
# Вы угадали число! Это число = 98, за 7 попыток
# Вы угадали число! Это число = 61, за 6 попыток
# Вы угадали число! Это число = 86, за 6 попыток
# Вы угадали число! Это число = 15, за 7 попыток
# Вы угадали число! Это число = 2, за 6 попыток
# Вы угадали число! Это число = 27, за 6 попыток
# Вы угадали число! Это число = 14, за 6 попыток
# Вы угадали число! Это число = 91, за 5 попыток
# Вы угадали число! Это число = 89, за 6 попыток
# Вы угадали число! Это число = 85, за 5 попыток
# Вы угадали число! Это число = 48, за 7 попыток
# Вы угадали число! Это число = 35, за 5 попыток
# Вы угадали число! Это число = 47, за 5 попыток
# Вы угадали число! Это число = 16, за 5 попыток
# Вы угадали число! Это число = 66, за 5 попыток
# Вы угадали число! Это число = 10, за 5 попыток
# Вы угадали число! Это число = 71, за 7 попыток
# Вы угадали число! Это число = 48, за 7 попыток
# Вы угадали число! Это число = 60, за 5 попыток
# Вы угадали число! Это число = 71, за 7 попыток
# Вы угадали число! Это число = 99, за 6 попыток
# Вы угадали число! Это число = 51, за 1 попыток
# Вы угадали число! Это число = 28, за 7 попыток
# Вы угадали число! Это число = 82, за 4 попыток
# Вы угадали число! Это число = 11, за 6 попыток
# Вы угадали число! Это число = 87, за 7 попыток
# Вы угадали число! Это число = 53, за 7 попыток
# Вы угадали число! Это число = 40, за 7 попыток
# Вы угадали число! Это число = 52, за 6 попыток
# Вы угадали число! Это число = 95, за 6 попыток
# Вы угадали число! Это число = 40, за 7 попыток
# Вы угадали число! Это число = 43, за 7 попыток
# Вы угадали число! Это число = 77, за 6 попыток
# Вы угадали число! Это число = 46, за 7 попыток
# Вы угадали число! Это число = 2, за 6 попыток
# Вы угадали число! Это число = 76, за 2 попыток
# Вы угадали число! Это число = 92, за 6 попыток
# Вы угадали число! Это число = 29, за 5 попыток
# Вы угадали число! Это число = 40, за 7 попыток
# Вы угадали число! Это число = 52, за 6 попыток
# Вы угадали число! Это число = 21, за 7 попыток
# Вы угадали число! Это число = 89, за 6 попыток
# Вы угадали число! Это число = 82, за 4 попыток
# Вы угадали число! Это число = 84, за 7 попыток
# Вы угадали число! Это число = 88, за 3 попыток
# Вы угадали число! Это число = 44, за 4 попыток
# Вы угадали число! Это число = 57, за 4 попыток
# Вы угадали число! Это число = 24, за 6 попыток
# Вы угадали число! Это число = 71, за 7 попыток
# Вы угадали число! Это число = 60, за 5 попыток
# Вы угадали число! Это число = 12, за 7 попыток
# Вы угадали число! Это число = 27, за 6 попыток
# Вы угадали число! Это число = 25, за 7 попыток
# Вы угадали число! Это число = 79, за 5 попыток
# Вы угадали число! Это число = 56, за 7 попыток
# Вы угадали число! Это число = 56, за 7 попыток
# Вы угадали число! Это число = 33, за 6 попыток
# Вы угадали число! Это число = 18, за 7 попыток
# Вы угадали число! Это число = 60, за 5 попыток
# Вы угадали число! Это число = 20, за 6 попыток
# Вы угадали число! Это число = 23, за 7 попыток
# Вы угадали число! Это число = 15, за 7 попыток
# Вы угадали число! Это число = 61, за 6 попыток
# Вы угадали число! Это число = 30, за 6 попыток
# Вы угадали число! Это число = 66, за 5 попыток
# Вы угадали число! Это число = 88, за 3 попыток
# Вы угадали число! Это число = 38, за 3 попыток
# Вы угадали число! Это число = 6, за 7 попыток
# Вы угадали число! Это число = 9, за 7 попыток
# Вы угадали число! Это число = 85, за 5 попыток
# Вы угадали число! Это число = 47, за 5 попыток
# Вы угадали число! Это число = 1, за 7 попыток
# Вы угадали число! Это число = 71, за 7 попыток
# Вы угадали число! Это число = 33, за 6 попыток
# Вы угадали число! Это число = 100, за 7 попыток
# Вы угадали число! Это число = 38, за 3 попыток
# Вы угадали число! Это число = 35, за 5 попыток
# Вы угадали число! Это число = 59, за 7 попыток
# Вы угадали число! Это число = 14, за 6 попыток
# Вы угадали число! Это число = 73, за 7 попыток
# Вы угадали число! Это число = 69, за 4 попыток
# Вы угадали число! Это число = 78, за 7 попыток
# Вы угадали число! Это число = 8, за 6 попыток
# Вы угадали число! Это число = 20, за 6 попыток
# Вы угадали число! Это число = 99, за 6 попыток
# Вы угадали число! Это число = 48, за 7 попыток
# Вы угадали число! Это число = 92, за 6 попыток
# Вы угадали число! Это число = 24, за 6 попыток
# Вы угадали число! Это число = 87, за 7 попыток
# Вы угадали число! Это число = 64, за 6 попыток
# Вы угадали число! Это число = 67, за 6 попыток
# Вы угадали число! Это число = 20, за 6 попыток
# Вы угадали число! Это число = 29, за 5 попыток
# Вы угадали число! Это число = 20, за 6 попыток
# Вы угадали число! Это число = 16, за 5 попыток
# Вы угадали число! Это число = 57, за 4 попыток
# Вы угадали число! Это число = 64, за 6 попыток
# Вы угадали число! Это число = 56, за 7 попыток
# Вы угадали число! Это число = 33, за 6 попыток
# Вы угадали число! Это число = 78, за 7 попыток
# Вы угадали число! Это число = 70, за 6 попыток
# Вы угадали число! Это число = 81, за 7 попыток
# Вы угадали число! Это число = 28, за 7 попыток
# Вы угадали число! Это число = 77, за 6 попыток
# Вы угадали число! Это число = 53, за 7 попыток
# Вы угадали число! Это число = 82, за 4 попыток
# Вы угадали число! Это число = 63, за 3 попыток
# Вы угадали число! Это число = 20, за 6 попыток
# Вы угадали число! Это число = 46, за 7 попыток
# Вы угадали число! Это число = 33, за 6 попыток
# Вы угадали число! Это число = 42, за 6 попыток
# Вы угадали число! Это число = 34, за 7 попыток
# Вы угадали число! Это число = 9, за 7 попыток
# Вы угадали число! Это число = 86, за 6 попыток
# Вы угадали число! Это число = 34, за 7 попыток
# Вы угадали число! Это число = 72, за 5 попыток
# Вы угадали число! Это число = 6, за 7 попыток
# Вы угадали число! Это число = 32, за 4 попыток
# Вы угадали число! Это число = 88, за 3 попыток
# Вы угадали число! Это число = 95, за 6 попыток
# Вы угадали число! Это число = 9, за 7 попыток
# Вы угадали число! Это число = 13, за 3 попыток
# Вы угадали число! Это число = 36, за 6 попыток
# Вы угадали число! Это число = 77, за 6 попыток
# Вы угадали число! Это число = 50, за 7 попыток
# Вы угадали число! Это число = 7, за 4 попыток
# Вы угадали число! Это число = 49, за 6 попыток
# Вы угадали число! Это число = 74, за 6 попыток
# Вы угадали число! Это число = 42, за 6 попыток
# Вы угадали число! Это число = 66, за 5 попыток
# Вы угадали число! Это число = 35, за 5 попыток
# Вы угадали число! Это число = 65, за 7 попыток
# Вы угадали число! Это число = 20, за 6 попыток
# Вы угадали число! Это число = 39, за 6 попыток
# Вы угадали число! Это число = 76, за 2 попыток
# Вы угадали число! Это число = 46, за 7 попыток
# Вы угадали число! Это число = 59, за 7 попыток
# Вы угадали число! Это число = 40, за 7 попыток
# Вы угадали число! Это число = 21, за 7 попыток
# Вы угадали число! Это число = 35, за 5 попыток
# Вы угадали число! Это число = 35, за 5 попыток
# Вы угадали число! Это число = 32, за 4 попыток
# Вы угадали число! Это число = 39, за 6 попыток
# Вы угадали число! Это число = 91, за 5 попыток
# Вы угадали число! Это число = 85, за 5 попыток
# Вы угадали число! Это число = 70, за 6 попыток
# Вы угадали число! Это число = 25, за 7 попыток
# Вы угадали число! Это число = 58, за 6 попыток
# Вы угадали число! Это число = 20, за 6 попыток
# Вы угадали число! Это число = 37, за 7 попыток
# Вы угадали число! Это число = 57, за 4 попыток
# Вы угадали число! Это число = 1, за 7 попыток
# Вы угадали число! Это число = 3, за 7 попыток
# Вы угадали число! Это число = 45, за 6 попыток
# Вы угадали число! Это число = 55, за 6 попыток
# Вы угадали число! Это число = 10, за 5 попыток
# Вы угадали число! Это число = 36, за 6 попыток
# Вы угадали число! Это число = 73, за 7 попыток
# Вы угадали число! Это число = 1, за 7 попыток
# Вы угадали число! Это число = 16, за 5 попыток
# Вы угадали число! Это число = 19, за 4 попыток
# Вы угадали число! Это число = 43, за 7 попыток
# Вы угадали число! Это число = 83, за 6 попыток
# Вы угадали число! Это число = 57, за 4 попыток
# Вы угадали число! Это число = 49, за 6 попыток
# Вы угадали число! Это число = 26, за 2 попыток
# Вы угадали число! Это число = 26, за 2 попыток
# Вы угадали число! Это число = 24, за 6 попыток
# Вы угадали число! Это число = 36, за 6 попыток
# Вы угадали число! Это число = 51, за 1 попыток
# Вы угадали число! Это число = 66, за 5 попыток
# Вы угадали число! Это число = 73, за 7 попыток
# Вы угадали число! Это число = 13, за 3 попыток
# Вы угадали число! Это число = 37, за 7 попыток
# Вы угадали число! Это число = 48, за 7 попыток
# Вы угадали число! Это число = 27, за 6 попыток
# Вы угадали число! Это число = 30, за 6 попыток
# Вы угадали число! Это число = 9, за 7 попыток
# Вы угадали число! Это число = 11, за 6 попыток
# Вы угадали число! Это число = 99, за 6 попыток
# Вы угадали число! Это число = 87, за 7 попыток
# Вы угадали число! Это число = 92, за 6 попыток
# Вы угадали число! Это число = 70, за 6 попыток
# Вы угадали число! Это число = 28, за 7 попыток
# Вы угадали число! Это число = 89, за 6 попыток
# Вы угадали число! Это число = 75, за 7 попыток
# Вы угадали число! Это число = 100, за 7 попыток
# Вы угадали число! Это число = 4, за 5 попыток
# Вы угадали число! Это число = 73, за 7 попыток
# Вы угадали число! Это число = 11, за 6 попыток
# Вы угадали число! Это число = 81, за 7 попыток
# Вы угадали число! Это число = 25, за 7 попыток
# Вы угадали число! Это число = 2, за 6 попыток
# Вы угадали число! Это число = 8, за 6 попыток
# Вы угадали число! Это число = 32, за 4 попыток
# Вы угадали число! Это число = 44, за 4 попыток
# Вы угадали число! Это число = 25, за 7 попыток
# Вы угадали число! Это число = 24, за 6 попыток
# Вы угадали число! Это число = 70, за 6 попыток
# Вы угадали число! Это число = 91, за 5 попыток
# Вы угадали число! Это число = 38, за 3 попыток
# Вы угадали число! Это число = 52, за 6 попыток
# Вы угадали число! Это число = 53, за 7 попыток
# Вы угадали число! Это число = 41, за 5 попыток
# Вы угадали число! Это число = 6, за 7 попыток
# Вы угадали число! Это число = 13, за 3 попыток
# Вы угадали число! Это число = 4, за 5 попыток
# Вы угадали число! Это число = 7, за 4 попыток
# Вы угадали число! Это число = 46, за 7 попыток
# Вы угадали число! Это число = 96, за 7 попыток
# Вы угадали число! Это число = 59, за 7 попыток
# Вы угадали число! Это число = 11, за 6 попыток
# Вы угадали число! Это число = 84, за 7 попыток
# Вы угадали число! Это число = 88, за 3 попыток
# Вы угадали число! Это число = 4, за 5 попыток
# Вы угадали число! Это число = 81, за 7 попыток
# Вы угадали число! Это число = 16, за 5 попыток
# Вы угадали число! Это число = 30, за 6 попыток
# Вы угадали число! Это число = 4, за 5 попыток
# Вы угадали число! Это число = 9, за 7 попыток
# Вы угадали число! Это число = 74, за 6 попыток
# Вы угадали число! Это число = 88, за 3 попыток
# Вы угадали число! Это число = 11, за 6 попыток
# Вы угадали число! Это число = 45, за 6 попыток
# Вы угадали число! Это число = 73, за 7 попыток
# Вы угадали число! Это число = 65, за 7 попыток
# Вы угадали число! Это число = 26, за 2 попыток
# Вы угадали число! Это число = 79, за 5 попыток
# Вы угадали число! Это число = 99, за 6 попыток
# Вы угадали число! Это число = 35, за 5 попыток
# Вы угадали число! Это число = 30, за 6 попыток
# Вы угадали число! Это число = 51, за 1 попыток
# Вы угадали число! Это число = 40, за 7 попыток
# Вы угадали число! Это число = 35, за 5 попыток
# Вы угадали число! Это число = 76, за 2 попыток
# Вы угадали число! Это число = 21, за 7 попыток
# Вы угадали число! Это число = 46, за 7 попыток
# Вы угадали число! Это число = 8, за 6 попыток
# Вы угадали число! Это число = 79, за 5 попыток
# Вы угадали число! Это число = 70, за 6 попыток
# Вы угадали число! Это число = 45, за 6 попыток
# Вы угадали число! Это число = 44, за 4 попыток
# Вы угадали число! Это число = 91, за 5 попыток
# Вы угадали число! Это число = 72, за 5 попыток
# Вы угадали число! Это число = 99, за 6 попыток
# Вы угадали число! Это число = 1, за 7 попыток
# Вы угадали число! Это число = 92, за 6 попыток
# Вы угадали число! Это число = 11, за 6 попыток
# Вы угадали число! Это число = 81, за 7 попыток
# Вы угадали число! Это число = 99, за 6 попыток
# Вы угадали число! Это число = 95, за 6 попыток
# Вы угадали число! Это число = 66, за 5 попыток
# Вы угадали число! Это число = 77, за 6 попыток
# Вы угадали число! Это число = 21, за 7 попыток
# Вы угадали число! Это число = 40, за 7 попыток
# Вы угадали число! Это число = 98, за 7 попыток
# Вы угадали число! Это число = 56, за 7 попыток
# Вы угадали число! Это число = 33, за 6 попыток
# Вы угадали число! Это число = 71, за 7 попыток
# Вы угадали число! Это число = 84, за 7 попыток
# Вы угадали число! Это число = 45, за 6 попыток
# Вы угадали число! Это число = 87, за 7 попыток
# Вы угадали число! Это число = 69, за 4 попыток
# Вы угадали число! Это число = 18, за 7 попыток
# Вы угадали число! Это число = 8, за 6 попыток
# Вы угадали число! Это число = 70, за 6 попыток
# Вы угадали число! Это число = 20, за 6 попыток
# Вы угадали число! Это число = 66, за 5 попыток
# Вы угадали число! Это число = 87, за 7 попыток
# Вы угадали число! Это число = 100, за 7 попыток
# Вы угадали число! Это число = 33, за 6 попыток
# Вы угадали число! Это число = 68, за 7 попыток
# Вы угадали число! Это число = 77, за 6 попыток
# Вы угадали число! Это число = 49, за 6 попыток
# Вы угадали число! Это число = 87, за 7 попыток
# Вы угадали число! Это число = 77, за 6 попыток
# Вы угадали число! Это число = 20, за 6 попыток
# Вы угадали число! Это число = 49, за 6 попыток
# Вы угадали число! Это число = 34, за 7 попыток
# Вы угадали число! Это число = 34, за 7 попыток
# Вы угадали число! Это число = 4, за 5 попыток
# Вы угадали число! Это число = 71, за 7 попыток
# Вы угадали число! Это число = 2, за 6 попыток
# Вы угадали число! Это число = 49, за 6 попыток
# Вы угадали число! Это число = 92, за 6 попыток
# Вы угадали число! Это число = 61, за 6 попыток
# Вы угадали число! Это число = 71, за 7 попыток
# Вы угадали число! Это число = 57, за 4 попыток
# Вы угадали число! Это число = 30, за 6 попыток
# Вы угадали число! Это число = 65, за 7 попыток
# Вы угадали число! Это число = 58, за 6 попыток
# Вы угадали число! Это число = 47, за 5 попыток
# Вы угадали число! Это число = 48, за 7 попыток
# Вы угадали число! Это число = 100, за 7 попыток
# Вы угадали число! Это число = 6, за 7 попыток
# Вы угадали число! Это число = 72, за 5 попыток
# Вы угадали число! Это число = 79, за 5 попыток
# Вы угадали число! Это число = 98, за 7 попыток
# Вы угадали число! Это число = 10, за 5 попыток
# Вы угадали число! Это число = 76, за 2 попыток
# Вы угадали число! Это число = 55, за 6 попыток
# Вы угадали число! Это число = 25, за 7 попыток
# Вы угадали число! Это число = 29, за 5 попыток
# Вы угадали число! Это число = 67, за 6 попыток
# Вы угадали число! Это число = 89, за 6 попыток
# Вы угадали число! Это число = 94, за 4 попыток
# Вы угадали число! Это число = 7, за 4 попыток
# Вы угадали число! Это число = 21, за 7 попыток
# Вы угадали число! Это число = 11, за 6 попыток
# Вы угадали число! Это число = 93, за 7 попыток
# Вы угадали число! Это число = 78, за 7 попыток
# Вы угадали число! Это число = 70, за 6 попыток
# Вы угадали число! Это число = 90, за 7 попыток
# Вы угадали число! Это число = 28, за 7 попыток
# Вы угадали число! Это число = 78, за 7 попыток
# Вы угадали число! Это число = 4, за 5 попыток
# Вы угадали число! Это число = 16, за 5 попыток
# Вы угадали число! Это число = 44, за 4 попыток
# Вы угадали число! Это число = 64, за 6 попыток
# Вы угадали число! Это число = 7, за 4 попыток
# Вы угадали число! Это число = 18, за 7 попыток
# Вы угадали число! Это число = 94, за 4 попыток
# Вы угадали число! Это число = 49, за 6 попыток
# Вы угадали число! Это число = 20, за 6 попыток
# Вы угадали число! Это число = 9, за 7 попыток
# Вы угадали число! Это число = 43, за 7 попыток
# Вы угадали число! Это число = 8, за 6 попыток
# Вы угадали число! Это число = 78, за 7 попыток
# Вы угадали число! Это число = 4, за 5 попыток
# Вы угадали число! Это число = 48, за 7 попыток
# Вы угадали число! Это число = 17, за 6 попыток
# Вы угадали число! Это число = 9, за 7 попыток
# Вы угадали число! Это число = 39, за 6 попыток
# Вы угадали число! Это число = 26, за 2 попыток
# Вы угадали число! Это число = 17, за 6 попыток
# Вы угадали число! Это число = 99, за 6 попыток
# Вы угадали число! Это число = 62, за 7 попыток
# Вы угадали число! Это число = 64, за 6 попыток
# Вы угадали число! Это число = 40, за 7 попыток
# Вы угадали число! Это число = 30, за 6 попыток
# Вы угадали число! Это число = 20, за 6 попыток
# Вы угадали число! Это число = 40, за 7 попыток
# Вы угадали число! Это число = 33, за 6 попыток
# Вы угадали число! Это число = 31, за 7 попыток
# Вы угадали число! Это число = 82, за 4 попыток
# Вы угадали число! Это число = 47, за 5 попыток
# Вы угадали число! Это число = 90, за 7 попыток
# Вы угадали число! Это число = 21, за 7 попыток
# Вы угадали число! Это число = 79, за 5 попыток
# Вы угадали число! Это число = 70, за 6 попыток
# Вы угадали число! Это число = 48, за 7 попыток
# Вы угадали число! Это число = 9, за 7 попыток
# Вы угадали число! Это число = 29, за 5 попыток
# Вы угадали число! Это число = 6, за 7 попыток
# Вы угадали число! Это число = 74, за 6 попыток
# Вы угадали число! Это число = 4, за 5 попыток
# Вы угадали число! Это число = 53, за 7 попыток
# Вы угадали число! Это число = 84, за 7 попыток
# Вы угадали число! Это число = 94, за 4 попыток
# Вы угадали число! Это число = 39, за 6 попыток
# Вы угадали число! Это число = 27, за 6 попыток
# Вы угадали число! Это число = 19, за 4 попыток
# Вы угадали число! Это число = 23, за 7 попыток
# Вы угадали число! Это число = 65, за 7 попыток
# Вы угадали число! Это число = 57, за 4 попыток
# Вы угадали число! Это число = 63, за 3 попыток
# Вы угадали число! Это число = 18, за 7 попыток
# Вы угадали число! Это число = 39, за 6 попыток
# Вы угадали число! Это число = 61, за 6 попыток
# Вы угадали число! Это число = 83, за 6 попыток
# Вы угадали число! Это число = 78, за 7 попыток
# Вы угадали число! Это число = 3, за 7 попыток
# Вы угадали число! Это число = 53, за 7 попыток
# Вы угадали число! Это число = 72, за 5 попыток
# Вы угадали число! Это число = 88, за 3 попыток
# Вы угадали число! Это число = 7, за 4 попыток
# Вы угадали число! Это число = 62, за 7 попыток
# Вы угадали число! Это число = 28, за 7 попыток
# Вы угадали число! Это число = 70, за 6 попыток
# Вы угадали число! Это число = 83, за 6 попыток
# Вы угадали число! Это число = 96, за 7 попыток
# Вы угадали число! Это число = 86, за 6 попыток
# Вы угадали число! Это число = 96, за 7 попыток
# Вы угадали число! Это число = 20, за 6 попыток
# Вы угадали число! Это число = 71, за 7 попыток
# Вы угадали число! Это число = 59, за 7 попыток
# Вы угадали число! Это число = 8, за 6 попыток
# Вы угадали число! Это число = 56, за 7 попыток
# Вы угадали число! Это число = 54, за 5 попыток
# Вы угадали число! Это число = 5, за 6 попыток
# Вы угадали число! Это число = 52, за 6 попыток
# Вы угадали число! Это число = 27, за 6 попыток
# Вы угадали число! Это число = 51, за 1 попыток
# Вы угадали число! Это число = 18, за 7 попыток
# Вы угадали число! Это число = 57, за 4 попыток
# Вы угадали число! Это число = 96, за 7 попыток
# Вы угадали число! Это число = 15, за 7 попыток
# Вы угадали число! Это число = 53, за 7 попыток
# Вы угадали число! Это число = 72, за 5 попыток
# Вы угадали число! Это число = 72, за 5 попыток
# Вы угадали число! Это число = 45, за 6 попыток
# Вы угадали число! Это число = 94, за 4 попыток
# Вы угадали число! Это число = 26, за 2 попыток
# Вы угадали число! Это число = 86, за 6 попыток
# Вы угадали число! Это число = 81, за 7 попыток
# Вы угадали число! Это число = 75, за 7 попыток
# Вы угадали число! Это число = 55, за 6 попыток
# Вы угадали число! Это число = 47, за 5 попыток
# Вы угадали число! Это число = 37, за 7 попыток
# Вы угадали число! Это число = 71, за 7 попыток
# Вы угадали число! Это число = 91, за 5 попыток
# Вы угадали число! Это число = 18, за 7 попыток
# Вы угадали число! Это число = 43, за 7 попыток
# Вы угадали число! Это число = 14, за 6 попыток
# Вы угадали число! Это число = 20, за 6 попыток
# Вы угадали число! Это число = 8, за 6 попыток
# Вы угадали число! Это число = 60, за 5 попыток
# Вы угадали число! Это число = 16, за 5 попыток
# Вы угадали число! Это число = 39, за 6 попыток
# Вы угадали число! Это число = 30, за 6 попыток
# Вы угадали число! Это число = 24, за 6 попыток
# Вы угадали число! Это число = 83, за 6 попыток
# Вы угадали число! Это число = 4, за 5 попыток
# Вы угадали число! Это число = 24, за 6 попыток
# Вы угадали число! Это число = 12, за 7 попыток
# Вы угадали число! Это число = 52, за 6 попыток
# Вы угадали число! Это число = 28, за 7 попыток
# Вы угадали число! Это число = 77, за 6 попыток
# Вы угадали число! Это число = 53, за 7 попыток
# Вы угадали число! Это число = 68, за 7 попыток
# Вы угадали число! Это число = 47, за 5 попыток
# Вы угадали число! Это число = 82, за 4 попыток
# Вы угадали число! Это число = 89, за 6 попыток
# Вы угадали число! Это число = 28, за 7 попыток
# Вы угадали число! Это число = 73, за 7 попыток
# Вы угадали число! Это число = 71, за 7 попыток
# Вы угадали число! Это число = 37, за 7 попыток
# Вы угадали число! Это число = 63, за 3 попыток
# Вы угадали число! Это число = 29, за 5 попыток
# Вы угадали число! Это число = 41, за 5 попыток
# Вы угадали число! Это число = 54, за 5 попыток
# Вы угадали число! Это число = 62, за 7 попыток
# Вы угадали число! Это число = 23, за 7 попыток
# Вы угадали число! Это число = 61, за 6 попыток
# Вы угадали число! Это число = 99, за 6 попыток
# Вы угадали число! Это число = 49, за 6 попыток
# Вы угадали число! Это число = 88, за 3 попыток
# Вы угадали число! Это число = 61, за 6 попыток
# Вы угадали число! Это число = 33, за 6 попыток
# Вы угадали число! Это число = 32, за 4 попыток
# Вы угадали число! Это число = 90, за 7 попыток
# Вы угадали число! Это число = 3, за 7 попыток
# Вы угадали число! Это число = 73, за 7 попыток
# Вы угадали число! Это число = 47, за 5 попыток
# Вы угадали число! Это число = 4, за 5 попыток
# Вы угадали число! Это число = 8, за 6 попыток
# Вы угадали число! Это число = 16, за 5 попыток
# Вы угадали число! Это число = 27, за 6 попыток
# Вы угадали число! Это число = 43, за 7 попыток
# Вы угадали число! Это число = 58, за 6 попыток
# Вы угадали число! Это число = 68, за 7 попыток
# Вы угадали число! Это число = 83, за 6 попыток
# Вы угадали число! Это число = 79, за 5 попыток
# Вы угадали число! Это число = 4, за 5 попыток
# Вы угадали число! Это число = 23, за 7 попыток
# Вы угадали число! Это число = 4, за 5 попыток
# Вы угадали число! Это число = 52, за 6 попыток
# Вы угадали число! Это число = 78, за 7 попыток
# Вы угадали число! Это число = 2, за 6 попыток
# Вы угадали число! Это число = 81, за 7 попыток
# Вы угадали число! Это число = 94, за 4 попыток
# Вы угадали число! Это число = 4, за 5 попыток
# Вы угадали число! Это число = 24, за 6 попыток
# Вы угадали число! Это число = 5, за 6 попыток
# Вы угадали число! Это число = 78, за 7 попыток
# Вы угадали число! Это число = 7, за 4 попыток
# Вы угадали число! Это число = 34, за 7 попыток
# Вы угадали число! Это число = 53, за 7 попыток
# Вы угадали число! Это число = 26, за 2 попыток
# Вы угадали число! Это число = 48, за 7 попыток
# Вы угадали число! Это число = 61, за 6 попыток
# Вы угадали число! Это число = 17, за 6 попыток
# Вы угадали число! Это число = 22, за 5 попыток
# Вы угадали число! Это число = 89, за 6 попыток
# Вы угадали число! Это число = 25, за 7 попыток
# Вы угадали число! Это число = 54, за 5 попыток
# Вы угадали число! Это число = 69, за 4 попыток
# Вы угадали число! Это число = 55, за 6 попыток
# Вы угадали число! Это число = 85, за 5 попыток
# Вы угадали число! Это число = 12, за 7 попыток
# Вы угадали число! Это число = 22, за 5 попыток
# Вы угадали число! Это число = 51, за 1 попыток
# Вы угадали число! Это число = 21, за 7 попыток
# Вы угадали число! Это число = 59, за 7 попыток
# Вы угадали число! Это число = 90, за 7 попыток
# Вы угадали число! Это число = 68, за 7 попыток
# Вы угадали число! Это число = 64, за 6 попыток
# Вы угадали число! Это число = 71, за 7 попыток
# Вы угадали число! Это число = 67, за 6 попыток
# Вы угадали число! Это число = 82, за 4 попыток
# Вы угадали число! Это число = 57, за 4 попыток
# Вы угадали число! Это число = 92, за 6 попыток
# Вы угадали число! Это число = 4, за 5 попыток
# Вы угадали число! Это число = 22, за 5 попыток
# Вы угадали число! Это число = 99, за 6 попыток
# Вы угадали число! Это число = 38, за 3 попыток
# Вы угадали число! Это число = 74, за 6 попыток
# Вы угадали число! Это число = 70, за 6 попыток
# Вы угадали число! Это число = 56, за 7 попыток
# Вы угадали число! Это число = 54, за 5 попыток
# Вы угадали число! Это число = 55, за 6 попыток
# Вы угадали число! Это число = 64, за 6 попыток
# Вы угадали число! Это число = 10, за 5 попыток
# Вы угадали число! Это число = 89, за 6 попыток
# Вы угадали число! Это число = 21, за 7 попыток
# Вы угадали число! Это число = 32, за 4 попыток
# Вы угадали число! Это число = 97, за 5 попыток
# Вы угадали число! Это число = 94, за 4 попыток
# Вы угадали число! Это число = 99, за 6 попыток
# Вы угадали число! Это число = 71, за 7 попыток
# Вы угадали число! Это число = 75, за 7 попыток
# Вы угадали число! Это число = 76, за 2 попыток
# Вы угадали число! Это число = 46, за 7 попыток
# Вы угадали число! Это число = 46, за 7 попыток
# Вы угадали число! Это число = 95, за 6 попыток
# Вы угадали число! Это число = 18, за 7 попыток
# Вы угадали число! Это число = 43, за 7 попыток
# Вы угадали число! Это число = 1, за 7 попыток
# Вы угадали число! Это число = 55, за 6 попыток
# Вы угадали число! Это число = 52, за 6 попыток
# Вы угадали число! Это число = 19, за 4 попыток
# Вы угадали число! Это число = 78, за 7 попыток
# Вы угадали число! Это число = 30, за 6 попыток
# Вы угадали число! Это число = 81, за 7 попыток
# Вы угадали число! Это число = 73, за 7 попыток
# Вы угадали число! Это число = 44, за 4 попыток
# Вы угадали число! Это число = 97, за 5 попыток
# Вы угадали число! Это число = 57, за 4 попыток
# Вы угадали число! Это число = 53, за 7 попыток
# Вы угадали число! Это число = 67, за 6 попыток
# Вы угадали число! Это число = 94, за 4 попыток
# Вы угадали число! Это число = 19, за 4 попыток
# Вы угадали число! Это число = 41, за 5 попыток
# Вы угадали число! Это число = 93, за 7 попыток
# Вы угадали число! Это число = 70, за 6 попыток
# Вы угадали число! Это число = 12, за 7 попыток
# Вы угадали число! Это число = 15, за 7 попыток
# Вы угадали число! Это число = 1, за 7 попыток
# Вы угадали число! Это число = 57, за 4 попыток
# Вы угадали число! Это число = 83, за 6 попыток
# Вы угадали число! Это число = 89, за 6 попыток
# Вы угадали число! Это число = 86, за 6 попыток
# Вы угадали число! Это число = 36, за 6 попыток
# Вы угадали число! Это число = 63, за 3 попыток
# Вы угадали число! Это число = 25, за 7 попыток
# Вы угадали число! Это число = 58, за 6 попыток
# Вы угадали число! Это число = 43, за 7 попыток
# Вы угадали число! Это число = 69, за 4 попыток
# Вы угадали число! Это число = 53, за 7 попыток
# Вы угадали число! Это число = 13, за 3 попыток
# Вы угадали число! Это число = 56, за 7 попыток
# Вы угадали число! Это число = 82, за 4 попыток
# Вы угадали число! Это число = 96, за 7 попыток
# Вы угадали число! Это число = 46, за 7 попыток
# Вы угадали число! Это число = 39, за 6 попыток
# Вы угадали число! Это число = 29, за 5 попыток
# Вы угадали число! Это число = 41, за 5 попыток
# Вы угадали число! Это число = 10, за 5 попыток
# Вы угадали число! Это число = 8, за 6 попыток
# Вы угадали число! Это число = 47, за 5 попыток
# Вы угадали число! Это число = 83, за 6 попыток
# Вы угадали число! Это число = 52, за 6 попыток
# Вы угадали число! Это число = 4, за 5 попыток
# Вы угадали число! Это число = 90, за 7 попыток
# Вы угадали число! Это число = 90, за 7 попыток
# Вы угадали число! Это число = 99, за 6 попыток
# Вы угадали число! Это число = 57, за 4 попыток
# Вы угадали число! Это число = 65, за 7 попыток
# Вы угадали число! Это число = 72, за 5 попыток
# Вы угадали число! Это число = 83, за 6 попыток
# Вы угадали число! Это число = 42, за 6 попыток
# Вы угадали число! Это число = 56, за 7 попыток
# Вы угадали число! Это число = 67, за 6 попыток
# Вы угадали число! Это число = 94, за 4 попыток
# Вы угадали число! Это число = 8, за 6 попыток
# Вы угадали число! Это число = 93, за 7 попыток
# Вы угадали число! Это число = 28, за 7 попыток
# Вы угадали число! Это число = 37, за 7 попыток
# Вы угадали число! Это число = 61, за 6 попыток
# Вы угадали число! Это число = 2, за 6 попыток
# Вы угадали число! Это число = 79, за 5 попыток
# Вы угадали число! Это число = 89, за 6 попыток
# Вы угадали число! Это число = 59, за 7 попыток
# Вы угадали число! Это число = 33, за 6 попыток
# Вы угадали число! Это число = 96, за 7 попыток
# Вы угадали число! Это число = 7, за 4 попыток
# Вы угадали число! Это число = 52, за 6 попыток
# Вы угадали число! Это число = 89, за 6 попыток
# Вы угадали число! Это число = 59, за 7 попыток
# Вы угадали число! Это число = 29, за 5 попыток
# Вы угадали число! Это число = 79, за 5 попыток
# Вы угадали число! Это число = 50, за 7 попыток
# Вы угадали число! Это число = 54, за 5 попыток
# Вы угадали число! Это число = 51, за 1 попыток
# Вы угадали число! Это число = 19, за 4 попыток
# Вы угадали число! Это число = 36, за 6 попыток
# Вы угадали число! Это число = 24, за 6 попыток
# Вы угадали число! Это число = 90, за 7 попыток
# Вы угадали число! Это число = 45, за 6 попыток
# Вы угадали число! Это число = 10, за 5 попыток
# Вы угадали число! Это число = 5, за 6 попыток
# Вы угадали число! Это число = 44, за 4 попыток
# Вы угадали число! Это число = 79, за 5 попыток
# Вы угадали число! Это число = 69, за 4 попыток
# Вы угадали число! Это число = 83, за 6 попыток
# Вы угадали число! Это число = 47, за 5 попыток
# Вы угадали число! Это число = 71, за 7 попыток
# Вы угадали число! Это число = 95, за 6 попыток
# Вы угадали число! Это число = 60, за 5 попыток
# Вы угадали число! Это число = 49, за 6 попыток
# Вы угадали число! Это число = 66, за 5 попыток
# Вы угадали число! Это число = 4, за 5 попыток
# Вы угадали число! Это число = 96, за 7 попыток
# Вы угадали число! Это число = 68, за 7 попыток
# Вы угадали число! Это число = 34, за 7 попыток
# Вы угадали число! Это число = 60, за 5 попыток
# Вы угадали число! Это число = 77, за 6 попыток
# Вы угадали число! Это число = 41, за 5 попыток
# Вы угадали число! Это число = 60, за 5 попыток
# Вы угадали число! Это число = 16, за 5 попыток
# Вы угадали число! Это число = 26, за 2 попыток
# Вы угадали число! Это число = 64, за 6 попыток
# Вы угадали число! Это число = 46, за 7 попыток
# Вы угадали число! Это число = 62, за 7 попыток
# Вы угадали число! Это число = 9, за 7 попыток
# Вы угадали число! Это число = 97, за 5 попыток
# Вы угадали число! Это число = 94, за 4 попыток
# Вы угадали число! Это число = 57, за 4 попыток
# Вы угадали число! Это число = 57, за 4 попыток
# Вы угадали число! Это число = 25, за 7 попыток
# Вы угадали число! Это число = 96, за 7 попыток
# Вы угадали число! Это число = 50, за 7 попыток
# Вы угадали число! Это число = 61, за 6 попыток
# Вы угадали число! Это число = 3, за 7 попыток
# Вы угадали число! Это число = 44, за 4 попыток
# Вы угадали число! Это число = 48, за 7 попыток
# Вы угадали число! Это число = 78, за 7 попыток
# Вы угадали число! Это число = 70, за 6 попыток
# Вы угадали число! Это число = 25, за 7 попыток
# Вы угадали число! Это число = 90, за 7 попыток
# Вы угадали число! Это число = 62, за 7 попыток
# Вы угадали число! Это число = 58, за 6 попыток
# Вы угадали число! Это число = 15, за 7 попыток
# Вы угадали число! Это число = 51, за 1 попыток
# Вы угадали число! Это число = 9, за 7 попыток
# Вы угадали число! Это число = 39, за 6 попыток
# Вы угадали число! Это число = 29, за 5 попыток
# Вы угадали число! Это число = 63, за 3 попыток
# Вы угадали число! Это число = 36, за 6 попыток
# Вы угадали число! Это число = 8, за 6 попыток
# Вы угадали число! Это число = 85, за 5 попыток
# Вы угадали число! Это число = 99, за 6 попыток
# Вы угадали число! Это число = 69, за 4 попыток
# Вы угадали число! Это число = 67, за 6 попыток
# Вы угадали число! Это число = 93, за 7 попыток
# Вы угадали число! Это число = 63, за 3 попыток
# Вы угадали число! Это число = 55, за 6 попыток
# Вы угадали число! Это число = 68, за 7 попыток
# Вы угадали число! Это число = 7, за 4 попыток
# Вы угадали число! Это число = 22, за 5 попыток
# Вы угадали число! Это число = 43, за 7 попыток
# Вы угадали число! Это число = 91, за 5 попыток
# Вы угадали число! Это число = 68, за 7 попыток
# Вы угадали число! Это число = 23, за 7 попыток
# Вы угадали число! Это число = 45, за 6 попыток
# Вы угадали число! Это число = 97, за 5 попыток
# Вы угадали число! Это число = 8, за 6 попыток
# Вы угадали число! Это число = 7, за 4 попыток
# Вы угадали число! Это число = 49, за 6 попыток
# Вы угадали число! Это число = 5, за 6 попыток
# Вы угадали число! Это число = 53, за 7 попыток
# Вы угадали число! Это число = 8, за 6 попыток
# Вы угадали число! Это число = 51, за 1 попыток
# Вы угадали число! Это число = 16, за 5 попыток
# Вы угадали число! Это число = 68, за 7 попыток
# Вы угадали число! Это число = 53, за 7 попыток
# Вы угадали число! Это число = 86, за 6 попыток
# Вы угадали число! Это число = 41, за 5 попыток
# Вы угадали число! Это число = 86, за 6 попыток
# Вы угадали число! Это число = 82, за 4 попыток
# Вы угадали число! Это число = 27, за 6 попыток
# Вы угадали число! Это число = 61, за 6 попыток
# Вы угадали число! Это число = 93, за 7 попыток
# Вы угадали число! Это число = 12, за 7 попыток
# Вы угадали число! Это число = 52, за 6 попыток
# Вы угадали число! Это число = 55, за 6 попыток
# Вы угадали число! Это число = 6, за 7 попыток
# Вы угадали число! Это число = 43, за 7 попыток
# Вы угадали число! Это число = 30, за 6 попыток
# Вы угадали число! Это число = 52, за 6 попыток
# Вы угадали число! Это число = 22, за 5 попыток
# Вы угадали число! Это число = 18, за 7 попыток
# Вы угадали число! Это число = 60, за 5 попыток
# Вы угадали число! Это число = 20, за 6 попыток
# Вы угадали число! Это число = 32, за 4 попыток
# Вы угадали число! Это число = 40, за 7 попыток
# Вы угадали число! Это число = 13, за 3 попыток
# Вы угадали число! Это число = 9, за 7 попыток
# Вы угадали число! Это число = 54, за 5 попыток
# Вы угадали число! Это число = 80, за 6 попыток
# Вы угадали число! Это число = 85, за 5 попыток
# Вы угадали число! Это число = 98, за 7 попыток
# Вы угадали число! Это число = 79, за 5 попыток
# Вы угадали число! Это число = 30, за 6 попыток
# Вы угадали число! Это число = 14, за 6 попыток
# Вы угадали число! Это число = 24, за 6 попыток
# Вы угадали число! Это число = 60, за 5 попыток
# Вы угадали число! Это число = 37, за 7 попыток
# Вы угадали число! Это число = 26, за 2 попыток
# Вы угадали число! Это число = 33, за 6 попыток
# Вы угадали число! Это число = 57, за 4 попыток
# Вы угадали число! Это число = 70, за 6 попыток
# Вы угадали число! Это число = 60, за 5 попыток
# Вы угадали число! Это число = 34, за 7 попыток
# Вы угадали число! Это число = 62, за 7 попыток
# Вы угадали число! Это число = 93, за 7 попыток
# Вы угадали число! Это число = 74, за 6 попыток
# Вы угадали число! Это число = 61, за 6 попыток
# Вы угадали число! Это число = 49, за 6 попыток
# Вы угадали число! Это число = 89, за 6 попыток
# Вы угадали число! Это число = 29, за 5 попыток
# Вы угадали число! Это число = 28, за 7 попыток
# Вы угадали число! Это число = 77, за 6 попыток
# ...
# Вы угадали число! Это число = 62, за 7 попыток
# Вы угадали число! Это число = 74, за 6 попыток
# Вы угадали число! Это число = 41, за 5 попыток
# Вы угадали число! Это число = 73, за 7 попыток
# Вы угадали число! Это число = 85, за 5 попыток
# Вы угадали число! Это число = 59, за 7 попыток
# Вы угадали число! Это число = 54, за 5 попыток
# Вы угадали число! Это число = 92, за 6 попыток
# Вы угадали число! Это число = 37, за 7 попыток
# Вы угадали число! Это число = 69, за 4 попыток
# Вы угадали число! Это число = 75, за 7 попыток
# Вы угадали число! Это число = 17, за 6 попыток
# Вы угадали число! Это число = 70, за 6 попыток
# Вы угадали число! Это число = 38, за 3 попыток
# Вы угадали число! Это число = 10, за 5 попыток
# Вы угадали число! Это число = 86, за 6 попыток
# Вы угадали число! Это число = 70, за 6 попыток
# Вы угадали число! Это число = 39, за 6 попыток
# Вы угадали число! Это число = 90, за 7 попыток
# Вы угадали число! Это число = 72, за 5 попыток
# Вы угадали число! Это число = 17, за 6 попыток
# Вы угадали число! Это число = 94, за 4 попыток
# Вы угадали число! Это число = 82, за 4 попыток
# Вы угадали число! Это число = 20, за 6 попыток
# Вы угадали число! Это число = 13, за 3 попыток
# Вы угадали число! Это число = 61, за 6 попыток
# Вы угадали число! Это число = 8, за 6 попыток
# Вы угадали число! Это число = 28, за 7 попыток
# Вы угадали число! Это число = 99, за 6 попыток
# Вы угадали число! Это число = 99, за 6 попыток
# Вы угадали число! Это число = 72, за 5 попыток
# Вы угадали число! Это число = 63, за 3 попыток
# Вы угадали число! Это число = 53, за 7 попыток
# Вы угадали число! Это число = 69, за 4 попыток
# Вы угадали число! Это число = 50, за 7 попыток
# Вы угадали число! Это число = 31, за 7 попыток
# Вы угадали число! Это число = 23, за 7 попыток
# Вы угадали число! Это число = 28, за 7 попыток
# Вы угадали число! Это число = 47, за 5 попыток
# Вы угадали число! Это число = 85, за 5 попыток
# Вы угадали число! Это число = 74, за 6 попыток
# Вы угадали число! Это число = 15, за 7 попыток
# Вы угадали число! Это число = 19, за 4 попыток
# Вы угадали число! Это число = 88, за 3 попыток
# Вы угадали число! Это число = 43, за 7 попыток
# Вы угадали число! Это число = 60, за 5 попыток
# Вы угадали число! Это число = 13, за 3 попыток
# Вы угадали число! Это число = 15, за 7 попыток
# Вы угадали число! Это число = 69, за 4 попыток
# Вы угадали число! Это число = 37, за 7 попыток
# Вы угадали число! Это число = 30, за 6 попыток
# Вы угадали число! Это число = 82, за 4 попыток
# Вы угадали число! Это число = 81, за 7 попыток
# Вы угадали число! Это число = 93, за 7 попыток
# Вы угадали число! Это число = 80, за 6 попыток
# Вы угадали число! Это число = 87, за 7 попыток
# Вы угадали число! Это число = 52, за 6 попыток
# Вы угадали число! Это число = 66, за 5 попыток
# Вы угадали число! Это число = 54, за 5 попыток
# Вы угадали число! Это число = 29, за 5 попыток
# Вы угадали число! Это число = 98, за 7 попыток
# Вы угадали число! Это число = 48, за 7 попыток
# Вы угадали число! Это число = 76, за 2 попыток
# Вы угадали число! Это число = 76, за 2 попыток
# Вы угадали число! Это число = 67, за 6 попыток
# Вы угадали число! Это число = 8, за 6 попыток
# Вы угадали число! Это число = 22, за 5 попыток
# Вы угадали число! Это число = 66, за 5 попыток
# Вы угадали число! Это число = 73, за 7 попыток
# Вы угадали число! Это число = 15, за 7 попыток
# Вы угадали число! Это число = 54, за 5 попыток
# Вы угадали число! Это число = 64, за 6 попыток
# Вы угадали число! Это число = 4, за 5 попыток
# Вы угадали число! Это число = 96, за 7 попыток
# Вы угадали число! Это число = 96, за 7 попыток
# Вы угадали число! Это число = 45, за 6 попыток
# Вы угадали число! Это число = 11, за 6 попыток
# Вы угадали число! Это число = 17, за 6 попыток
# Вы угадали число! Это число = 29, за 5 попыток
# Вы угадали число! Это число = 28, за 7 попыток
# Вы угадали число! Это число = 34, за 7 попыток
# Вы угадали число! Это число = 29, за 5 попыток
# Вы угадали число! Это число = 14, за 6 попыток
# Вы угадали число! Это число = 88, за 3 попыток
# Вы угадали число! Это число = 39, за 6 попыток
# Вы угадали число! Это число = 96, за 7 попыток
# Вы угадали число! Это число = 70, за 6 попыток
# Вы угадали число! Это число = 12, за 7 попыток
# Вы угадали число! Это число = 14, за 6 попыток
# Вы угадали число! Это число = 24, за 6 попыток
# Вы угадали число! Это число = 77, за 6 попыток
# Вы угадали число! Это число = 41, за 5 попыток
# Вы угадали число! Это число = 82, за 4 попыток
# Вы угадали число! Это число = 31, за 7 попыток
# Вы угадали число! Это число = 58, за 6 попыток
# Вы угадали число! Это число = 46, за 7 попыток
# Вы угадали число! Это число = 75, за 7 попыток
# Вы угадали число! Это число = 86, за 6 попыток
# Вы угадали число! Это число = 65, за 7 попыток
# Вы угадали число! Это число = 68, за 7 попыток
# Вы угадали число! Это число = 24, за 6 попыток
# Вы угадали число! Это число = 10, за 5 попыток
# Вы угадали число! Это число = 47, за 5 попыток
# Вы угадали число! Это число = 44, за 4 попыток
# Вы угадали число! Это число = 38, за 3 попыток
# Вы угадали число! Это число = 92, за 6 попыток
# Вы угадали число! Это число = 5, за 6 попыток
# Вы угадали число! Это число = 7, за 4 попыток
# Вы угадали число! Это число = 74, за 6 попыток
# Вы угадали число! Это число = 20, за 6 попыток
# Вы угадали число! Это число = 96, за 7 попыток
# Вы угадали число! Это число = 48, за 7 попыток
# Вы угадали число! Это число = 39, за 6 попыток
# Вы угадали число! Это число = 29, за 5 попыток
# Вы угадали число! Это число = 72, за 5 попыток
# Вы угадали число! Это число = 27, за 6 попыток
# Вы угадали число! Это число = 52, за 6 попыток
# Вы угадали число! Это число = 23, за 7 попыток
# Вы угадали число! Это число = 1, за 7 попыток
# Вы угадали число! Это число = 97, за 5 попыток
# Вы угадали число! Это число = 59, за 7 попыток
# Вы угадали число! Это число = 7, за 4 попыток
# Вы угадали число! Это число = 66, за 5 попыток
# Вы угадали число! Это число = 8, за 6 попыток
# Вы угадали число! Это число = 54, за 5 попыток
# Вы угадали число! Это число = 67, за 6 попыток
# Вы угадали число! Это число = 66, за 5 попыток
# Вы угадали число! Это число = 39, за 6 попыток
# Вы угадали число! Это число = 26, за 2 попыток
# Вы угадали число! Это число = 18, за 7 попыток
# Вы угадали число! Это число = 32, за 4 попыток
# Вы угадали число! Это число = 10, за 5 попыток
# Вы угадали число! Это число = 100, за 7 попыток
# Вы угадали число! Это число = 30, за 6 попыток
# Вы угадали число! Это число = 25, за 7 попыток
# Вы угадали число! Это число = 50, за 7 попыток
# Вы угадали число! Это число = 74, за 6 попыток
# Вы угадали число! Это число = 40, за 7 попыток
# Вы угадали число! Это число = 78, за 7 попыток
# Вы угадали число! Это число = 60, за 5 попыток
# Вы угадали число! Это число = 94, за 4 попыток
# Вы угадали число! Это число = 88, за 3 попыток
# Вы угадали число! Это число = 13, за 3 попыток
# Вы угадали число! Это число = 76, за 2 попыток
# Вы угадали число! Это число = 42, за 6 попыток
# Вы угадали число! Это число = 45, за 6 попыток
# Вы угадали число! Это число = 1, за 7 попыток
# Вы угадали число! Это число = 42, за 6 попыток
# Вы угадали число! Это число = 5, за 6 попыток
# Вы угадали число! Это число = 92, за 6 попыток
# Вы угадали число! Это число = 14, за 6 попыток
# Вы угадали число! Это число = 47, за 5 попыток
# Вы угадали число! Это число = 65, за 7 попыток
# Вы угадали число! Это число = 41, за 5 попыток
# Вы угадали число! Это число = 58, за 6 попыток
# Вы угадали число! Это число = 37, за 7 попыток
# Вы угадали число! Это число = 94, за 4 попыток
# Вы угадали число! Это число = 38, за 3 попыток
# Вы угадали число! Это число = 44, за 4 попыток
# Вы угадали число! Это число = 15, за 7 попыток
# Вы угадали число! Это число = 79, за 5 попыток
# Вы угадали число! Это число = 1, за 7 попыток
# Вы угадали число! Это число = 89, за 6 попыток
# Вы угадали число! Это число = 72, за 5 попыток
# Вы угадали число! Это число = 80, за 6 попыток
# Вы угадали число! Это число = 46, за 7 попыток
# Вы угадали число! Это число = 44, за 4 попыток
# Вы угадали число! Это число = 61, за 6 попыток
# Вы угадали число! Это число = 8, за 6 попыток
# Вы угадали число! Это число = 72, за 5 попыток
# Вы угадали число! Это число = 80, за 6 попыток
# Вы угадали число! Это число = 69, за 4 попыток
# Вы угадали число! Это число = 51, за 1 попыток
# Вы угадали число! Это число = 41, за 5 попыток
# Вы угадали число! Это число = 37, за 7 попыток
# Вы угадали число! Это число = 6, за 7 попыток
# Вы угадали число! Это число = 29, за 5 попыток
# Вы угадали число! Это число = 18, за 7 попыток
# Вы угадали число! Это число = 39, за 6 попыток
# Вы угадали число! Это число = 12, за 7 попыток
# Вы угадали число! Это число = 16, за 5 попыток
# Вы угадали число! Это число = 22, за 5 попыток
# Вы угадали число! Это число = 45, за 6 попыток
# Вы угадали число! Это число = 18, за 7 попыток
# Вы угадали число! Это число = 42, за 6 попыток
# Вы угадали число! Это число = 69, за 4 попыток
# Вы угадали число! Это число = 68, за 7 попыток
# Вы угадали число! Это число = 42, за 6 попыток
# Вы угадали число! Это число = 37, за 7 попыток
# Вы угадали число! Это число = 81, за 7 попыток
# Вы угадали число! Это число = 10, за 5 попыток
# Вы угадали число! Это число = 21, за 7 попыток
# Вы угадали число! Это число = 96, за 7 попыток
# Вы угадали число! Это число = 68, за 7 попыток
# Вы угадали число! Это число = 58, за 6 попыток
# Вы угадали число! Это число = 73, за 7 попыток
# Вы угадали число! Это число = 63, за 3 попыток
# Вы угадали число! Это число = 34, за 7 попыток
# Вы угадали число! Это число = 55, за 6 попыток
# Вы угадали число! Это число = 86, за 6 попыток
# Вы угадали число! Это число = 80, за 6 попыток
# Вы угадали число! Это число = 90, за 7 попыток
# Вы угадали число! Это число = 37, за 7 попыток
# Вы угадали число! Это число = 98, за 7 попыток
# Вы угадали число! Это число = 53, за 7 попыток
# Вы угадали число! Это число = 28, за 7 попыток
# Вы угадали число! Это число = 31, за 7 попыток
# Вы угадали число! Это число = 83, за 6 попыток
# Вы угадали число! Это число = 50, за 7 попыток
# Вы угадали число! Это число = 97, за 5 попыток
# Вы угадали число! Это число = 22, за 5 попыток
# Вы угадали число! Это число = 40, за 7 попыток
# Вы угадали число! Это число = 93, за 7 попыток
# Вы угадали число! Это число = 8, за 6 попыток
# Вы угадали число! Это число = 65, за 7 попыток
# Вы угадали число! Это число = 83, за 6 попыток
# Вы угадали число! Это число = 50, за 7 попыток
# Вы угадали число! Это число = 15, за 7 попыток
# Вы угадали число! Это число = 5, за 6 попыток
# Вы угадали число! Это число = 76, за 2 попыток
# Вы угадали число! Это число = 29, за 5 попыток
# Вы угадали число! Это число = 8, за 6 попыток
# Вы угадали число! Это число = 2, за 6 попыток
# Вы угадали число! Это число = 62, за 7 попыток
# Вы угадали число! Это число = 80, за 6 попыток
# Вы угадали число! Это число = 10, за 5 попыток
# Вы угадали число! Это число = 87, за 7 попыток
# Вы угадали число! Это число = 78, за 7 попыток
# Вы угадали число! Это число = 89, за 6 попыток
# Вы угадали число! Это число = 46, за 7 попыток
# Вы угадали число! Это число = 100, за 7 попыток
# Вы угадали число! Это число = 53, за 7 попыток
# Вы угадали число! Это число = 95, за 6 попыток
# Вы угадали число! Это число = 21, за 7 попыток
# Вы угадали число! Это число = 82, за 4 попыток
# Вы угадали число! Это число = 45, за 6 попыток
# Вы угадали число! Это число = 41, за 5 попыток
# Вы угадали число! Это число = 11, за 6 попыток
# Вы угадали число! Это число = 14, за 6 попыток
# Вы угадали число! Это число = 66, за 5 попыток
# Вы угадали число! Это число = 27, за 6 попыток
# Вы угадали число! Это число = 44, за 4 попыток
# Вы угадали число! Это число = 11, за 6 попыток
# Вы угадали число! Это число = 27, за 6 попыток
# Вы угадали число! Это число = 9, за 7 попыток
# Вы угадали число! Это число = 13, за 3 попыток
# Вы угадали число! Это число = 5, за 6 попыток
# Вы угадали число! Это число = 24, за 6 попыток
# Вы угадали число! Это число = 98, за 7 попыток
# Вы угадали число! Это число = 70, за 6 попыток
# Вы угадали число! Это число = 93, за 7 попыток
# Вы угадали число! Это число = 13, за 3 попыток
# Вы угадали число! Это число = 28, за 7 попыток
# Вы угадали число! Это число = 36, за 6 попыток
# Вы угадали число! Это число = 71, за 7 попыток
# Вы угадали число! Это число = 78, за 7 попыток
# Вы угадали число! Это число = 71, за 7 попыток
# Вы угадали число! Это число = 97, за 5 попыток
# Вы угадали число! Это число = 94, за 4 попыток
# Вы угадали число! Это число = 61, за 6 попыток
# Вы угадали число! Это число = 36, за 6 попыток
# Вы угадали число! Это число = 93, за 7 попыток
# Вы угадали число! Это число = 59, за 7 попыток
# Вы угадали число! Это число = 86, за 6 попыток
# Вы угадали число! Это число = 53, за 7 попыток
# Вы угадали число! Это число = 38, за 3 попыток
# Вы угадали число! Это число = 86, за 6 попыток
# Вы угадали число! Это число = 64, за 6 попыток
# Вы угадали число! Это число = 91, за 5 попыток
# Вы угадали число! Это число = 34, за 7 попыток
# Вы угадали число! Это число = 18, за 7 попыток
# Вы угадали число! Это число = 25, за 7 попыток
# Вы угадали число! Это число = 55, за 6 попыток
# Вы угадали число! Это число = 10, за 5 попыток
# Вы угадали число! Это число = 87, за 7 попыток
# Вы угадали число! Это число = 81, за 7 попыток
# Вы угадали число! Это число = 13, за 3 попыток
# Вы угадали число! Это число = 34, за 7 попыток
# Вы угадали число! Это число = 53, за 7 попыток
# Вы угадали число! Это число = 61, за 6 попыток
# Вы угадали число! Это число = 26, за 2 попыток
# Вы угадали число! Это число = 14, за 6 попыток
# Вы угадали число! Это число = 82, за 4 попыток
# Вы угадали число! Это число = 89, за 6 попыток
# Вы угадали число! Это число = 57, за 4 попыток
# Вы угадали число! Это число = 81, за 7 попыток
# Вы угадали число! Это число = 51, за 1 попыток
# Вы угадали число! Это число = 55, за 6 попыток
# Вы угадали число! Это число = 34, за 7 попыток
# Вы угадали число! Это число = 97, за 5 попыток
# Вы угадали число! Это число = 29, за 5 попыток
# Вы угадали число! Это число = 31, за 7 попыток
# Вы угадали число! Это число = 99, за 6 попыток
# Вы угадали число! Это число = 3, за 7 попыток
# Вы угадали число! Это число = 43, за 7 попыток
# Вы угадали число! Это число = 34, за 7 попыток
# Вы угадали число! Это число = 98, за 7 попыток
# Вы угадали число! Это число = 70, за 6 попыток
# Вы угадали число! Это число = 35, за 5 попыток
# Вы угадали число! Это число = 51, за 1 попыток
# Вы угадали число! Это число = 62, за 7 попыток
# Вы угадали число! Это число = 71, за 7 попыток
# Вы угадали число! Это число = 95, за 6 попыток
# Вы угадали число! Это число = 66, за 5 попыток
# Вы угадали число! Это число = 84, за 7 попыток
# Вы угадали число! Это число = 88, за 3 попыток
# Вы угадали число! Это число = 95, за 6 попыток
# Вы угадали число! Это число = 48, за 7 попыток
# Вы угадали число! Это число = 63, за 3 попыток
# Вы угадали число! Это число = 37, за 7 попыток
# Вы угадали число! Это число = 3, за 7 попыток
# Вы угадали число! Это число = 47, за 5 попыток
# Вы угадали число! Это число = 28, за 7 попыток
# Вы угадали число! Это число = 70, за 6 попыток
# Вы угадали число! Это число = 46, за 7 попыток
# Вы угадали число! Это число = 1, за 7 попыток
# Вы угадали число! Это число = 88, за 3 попыток
# Вы угадали число! Это число = 21, за 7 попыток
# Вы угадали число! Это число = 52, за 6 попыток
# Вы угадали число! Это число = 1, за 7 попыток
# Вы угадали число! Это число = 84, за 7 попыток
# Вы угадали число! Это число = 22, за 5 попыток
# Вы угадали число! Это число = 31, за 7 попыток
# Вы угадали число! Это число = 20, за 6 попыток
# Вы угадали число! Это число = 81, за 7 попыток
# Вы угадали число! Это число = 84, за 7 попыток
# Вы угадали число! Это число = 1, за 7 попыток
# Вы угадали число! Это число = 62, за 7 попыток
# Вы угадали число! Это число = 9, за 7 попыток
# Вы угадали число! Это число = 33, за 6 попыток
# Вы угадали число! Это число = 87, за 7 попыток
# Вы угадали число! Это число = 92, за 6 попыток
# Вы угадали число! Это число = 99, за 6 попыток
# Вы угадали число! Это число = 94, за 4 попыток
# Вы угадали число! Это число = 78, за 7 попыток
# Вы угадали число! Это число = 91, за 5 попыток
# Вы угадали число! Это число = 67, за 6 попыток
# Вы угадали число! Это число = 53, за 7 попыток
# Вы угадали число! Это число = 22, за 5 попыток
# Ваш алгоритм угадывает число в среднем за: 5 попытки

# %% [markdown]
# Напомним, что для успешного решения задания программа должна угадывать число меньше чем за 20 попыток!
