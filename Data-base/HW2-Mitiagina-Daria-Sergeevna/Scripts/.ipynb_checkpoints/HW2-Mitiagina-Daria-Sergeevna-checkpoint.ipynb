# %%
### DataFrame Preparation

# %%
import numpy as np
import pandas as pd

# %%
# Let's take a look at the Customer_table

# %%
customer_table =  pd.read_csv("../Tables/customer.csv", sep=';')
customer_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   customer_id            4000 non-null   int64
#  1   first_name             4000 non-null   object
#  2   last_name              3875 non-null   object
#  3   gender                 4000 non-null   object
#  4   DOB                    3913 non-null   object
#  5   job_title              3494 non-null   object
#  6   job_industry_category  3344 non-null   object
#  7   wealth_segment         4000 non-null   object
#  8   deceased_indicator     4000 non-null   object
#  9   owns_car               4000 non-null   object
#  10  address                4000 non-null   object
#  11  postcode               4000 non-null   int64
#  12  state                  4000 non-null   object
#  13  country                4000 non-null   object
#  14  property_valuation     4000 non-null   int64
# dtypes: int64(3), object(12)
# memory usage: 468.9+ KB

# %%
customer_table.head()
# Out:
#    customer_id      first_name  last_name  gender         DOB  \
# 0            1         Laraine  Medendorp       F  1953-10-12
# 1            2             Eli    Bockman    Male  1980-12-16
# 2            3           Arlin     Dearle    Male  1954-01-20
# 3            4          Talbot        NaN    Male  1961-10-03
# 4            5  Sheila-kathryn     Calton  Female  1977-05-13
#
#                 job_title job_industry_category     wealth_segment  \
# 0     Executive Secretary                Health      Mass Customer
# 1  Administrative Officer    Financial Services      Mass Customer
# 2      Recruiting Manager              Property      Mass Customer
# 3                     NaN                    IT      Mass Customer
# 4           Senior Editor                   NaN  Affluent Customer
#
#   deceased_indicator owns_car              address  postcode            state  \
# 0                  N      Yes   060 Morning Avenue      2016  New South Wales
# 1                  N      Yes  6 Meadow Vale Court      2153  New South Wales
# 2                  N      Yes   0 Holy Cross Court      4211              QLD
# 3                  N       No  17979 Del Mar Point      2448  New South Wales
# 4                  N      Yes     9 Oakridge Court      3216              VIC
#
#      country  property_valuation
# 0  Australia                  10
# 1  Australia                  10
# 2  Australia                   9
# 3  Australia                   4
# 4  Australia                   9

# %%
### What needs to be done judging by the first look at the table:
# - Need to get rid of null values

# %%
customer_table = customer_table.fillna('')

# Expect to see : there are no null values
customer_table.head()
# Out:
#    customer_id      first_name  last_name  gender         DOB  \
# 0            1         Laraine  Medendorp       F  1953-10-12
# 1            2             Eli    Bockman    Male  1980-12-16
# 2            3           Arlin     Dearle    Male  1954-01-20
# 3            4          Talbot               Male  1961-10-03
# 4            5  Sheila-kathryn     Calton  Female  1977-05-13
#
#                 job_title job_industry_category     wealth_segment  \
# 0     Executive Secretary                Health      Mass Customer
# 1  Administrative Officer    Financial Services      Mass Customer
# 2      Recruiting Manager              Property      Mass Customer
# 3                                            IT      Mass Customer
# 4           Senior Editor                        Affluent Customer
#
#   deceased_indicator owns_car              address  postcode            state  \
# 0                  N      Yes   060 Morning Avenue      2016  New South Wales
# 1                  N      Yes  6 Meadow Vale Court      2153  New South Wales
# 2                  N      Yes   0 Holy Cross Court      4211              QLD
# 3                  N       No  17979 Del Mar Point      2448  New South Wales
# 4                  N      Yes     9 Oakridge Court      3216              VIC
#
#      country  property_valuation
# 0  Australia                  10
# 1  Australia                  10
# 2  Australia                   9
# 3  Australia                   4
# 4  Australia                   9

# %%
# Let's take a look at the Transaction_table

# %%
transaction_table = pd.read_csv("../Tables/transaction.csv", sep=';')
transaction_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction_id    20000 non-null  int64
#  1   product_id        20000 non-null  int64
#  2   customer_id       20000 non-null  int64
#  3   transaction_date  20000 non-null  object
#  4   online_order      19640 non-null  object
#  5   order_status      20000 non-null  object
#  6   brand             19803 non-null  object
#  7   product_line      19803 non-null  object
#  8   product_class     19803 non-null  object
#  9   product_size      19803 non-null  object
#  10  list_price        20000 non-null  object
#  11  standard_cost     19803 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 1.8+ MB

# %%
transaction_table.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date online_order  \
# 0               1           2         2950       25.02.2017        False
# 1               2           3         3120       21.05.2017         True
# 2               3          37          402       16.10.2017        False
# 3               4          88         3135       31.08.2017        False
# 4               5          78          787       01.10.2017         True
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#   list_price standard_cost
# 0      71,49         53,62
# 1    2091,47        388,92
# 2    1793,43        248,82
# 3    1198,46        381,10
# 4     1765,3        709,48

# %%
### What needs to be done judging by the first look at the table:
# - Need to get rid of null values
# - Need to fix the float numbers format in list_price and standard_cost (',' -> '.')

# %%
transaction_table = transaction_table.fillna('')

def fix_float_format(x):
    return x.replace(',', '.')

transaction_table.standard_cost = transaction_table.standard_cost.apply(fix_float_format)
transaction_table.list_price    = transaction_table.list_price.apply(fix_float_format)

# Expect to see : there are no null values
transaction_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction_id    20000 non-null  int64
#  1   product_id        20000 non-null  int64
#  2   customer_id       20000 non-null  int64
#  3   transaction_date  20000 non-null  object
#  4   online_order      20000 non-null  object
#  5   order_status      20000 non-null  object
#  6   brand             20000 non-null  object
#  7   product_line      20000 non-null  object
#  8   product_class     20000 non-null  object
#  9   product_size      20000 non-null  object
#  10  list_price        20000 non-null  object
#  11  standard_cost     20000 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 1.8+ MB

# %%
# Expect to see : data format is okay for list_price and standard_cost
transaction_table.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date online_order  \
# 0               1           2         2950       25.02.2017        False
# 1               2           3         3120       21.05.2017         True
# 2               3          37          402       16.10.2017        False
# 3               4          88         3135       31.08.2017        False
# 4               5          78          787       01.10.2017         True
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#   list_price standard_cost
# 0      71.49         53.62
# 1    2091.47        388.92
# 2    1793.43        248.82
# 3    1198.46        381.10
# 4     1765.3        709.48

# %%
### SQL Tables Creation
# In HW1 I worked entirely with the DBeaver interface, this time I would like to try working with SQL from Jupyter Notebook. Let's see how this goes.

# %%
# !pip install ipython-sql
# Out:
# Requirement already satisfied: ipython-sql in c:\users\darya\appdata\local\programs\python\python311\lib\site-packages (0.5.0)
# Requirement already satisfied: prettytable in c:\users\darya\appdata\local\programs\python\python311\lib\site-packages (from ipython-sql) (3.9.0)
# Requirement already satisfied: ipython in c:\users\darya\appdata\roaming\python\python311\site-packages (from ipython-sql) (8.12.0)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\darya\appdata\local\programs\python\python311\lib\site-packages (from ipython-sql) (2.0.27)
# Requirement already satisfied: sqlparse in c:\users\darya\appdata\local\programs\python\python311\lib\site-packages (from ipython-sql) (0.4.4)
# Requirement already satisfied: six in c:\users\darya\appdata\local\programs\python\python311\lib\site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in c:\users\darya\appdata\local\programs\python\python311\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\darya\appdata\local\programs\python\python311\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.9.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\darya\appdata\local\programs\python\python311\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.0.3)
# Requirement already satisfied: backcall in c:\users\darya\appdata\roaming\python\python311\site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: decorator in c:\users\darya\appdata\local\programs\python\python311\lib\site-packages (from ipython->ipython-sql) (4.4.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\darya\appdata\roaming\python\python311\site-packages (from ipython->ipython-sql) (0.18.2)
# Requirement already satisfied: matplotlib-inline in c:\users\darya\appdata\roaming\python\python311\site-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\darya\appdata\roaming\python\python311\site-packages (from ipython->ipython-sql) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\darya\appdata\roaming\python\python311\site-packages (from ipython->ipython-sql) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\darya\appdata\roaming\python\python311\site-packages (from ipython->ipython-sql) (2.14.0)
# Requirement already satisfied: stack-data in c:\users\darya\appdata\roaming\python\python311\site-packages (from ipython->ipython-sql) (0.6.2)
# Requirement already satisfied: traitlets>=5 in c:\users\darya\appdata\roaming\python\python311\site-packages (from ipython->ipython-sql) (5.9.0)
# Requirement already satisfied: colorama in c:\users\darya\appdata\local\programs\python\python311\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\darya\appdata\roaming\python\python311\site-packages (from prettytable->ipython-sql) (0.2.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\darya\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: executing>=1.2.0 in c:\users\darya\appdata\roaming\python\python311\site-packages (from stack-data->ipython->ipython-sql) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\darya\appdata\roaming\python\python311\site-packages (from stack-data->ipython->ipython-sql) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\darya\appdata\roaming\python\python311\site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# DEPRECATION: Loading egg at c:\users\darya\appdata\local\programs\python\python311\lib\site-packages\pydelay-0.1.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330

# %%
# %load_ext sql

# %%
# %sql postgresql://postgres:hjrjgthf@localhost/postgres

# %%
# %%sql
#
# CREATE TABLE if not exists "customers" (
#   "customer_id" integer PRIMARY KEY,
#   "first_name" varchar,
#   "last_name" varchar,
#   "gender" varchar,
#   "DOB" varchar,
#   "job_title" varchar,
#   "job_industry_category" varchar,
#   "wealth_segment" varchar,
#   "deceased_indicator" varchar,
#   "owns_car" varchar,
#   "address" varchar,
#   "postcode" varchar,
#   "state" varchar,
#   "country" varchar,
#   "property_valuation" integer
# );
#
# CREATE TABLE if not exists "transactions" (
#   "transaction_id" integer PRIMARY KEY,
#   "product_id" integer,
#   "customer_id" integer,
#   "transaction_date" varchar,
#   "online_order" varchar,
#   "order_status" varchar,
#   "brand" varchar,
#   "product_line" varchar,
#   "product_class" varchar,
#   "product_size" varchar,
#   "list_price" float(4),
#   "standard_cost" float(4)
# );
#
# ALTER TABLE "transactions" ADD FOREIGN KEY ("customer_id") REFERENCES "customers" ("customer_id");
# Out:
#  * postgresql://postgres:***@localhost/postgres
# Done.
# Done.
# Done.
# []

# %%
# Let's fill in the tables
for it, rows in customer_table.iterrows():
    # %sql INSERT INTO customers VALUES ({rows["customer_id"]},            \
                                      '{rows["first_name"]}',            \
                                      '{rows["last_name"]}',             \
                                      '{rows["gender"]}',                \
                                      '{rows["DOB"]}',                   \
                                      '{rows["job_title"]}',             \
                                      '{rows["job_industry_category"]}', \
                                      '{rows["wealth_segment"]}',        \
                                      '{rows["deceased_indicator"]})',   \
                                      '{rows["owns_car"]}',              \
                                      '{rows["address"]}',               \
                                      '{rows["postcode"]}',              \
                                      '{rows["state"]}',                 \
                                      '{rows["country"]}',               \
                                       {rows["property_valuation"]});
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# (psycopg2.errors.SyntaxError) ОШИБКА:  ошибка синтаксиса (примерное положение: "arcy")
# LINE 1: INSERT INTO customers VALUES (249, 'D' arcy', 'Slay' , 'Male...
#                                                ^
#
# [SQL: INSERT INTO customers VALUES (249, 'D' arcy', 'Slay' , 'Male' , '1992-09-13' , 'Quality Control Specialist' , 'IT' , 'High Net Worth' , 'N)' , 'No' , '77248 Columbus Drive' , '2340' , 'NSW' , 'Australia' , 7);]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# (psycopg2.errors.SyntaxError) ОШИБКА:  ошибка синтаксиса (примерное положение: "Kane")
# LINE 1: ...SERT INTO customers VALUES (409, 'Tatiania' , 'O' Kane', 'Fe...
#                                                              ^
#
# [SQL: INSERT INTO customers VALUES (409, 'Tatiania' , 'O' Kane', 'Female' , '1978-01-23' , 'Executive Secretary' , 'Health' , 'Mass Customer' , 'N)' , 'Yes' , '17 Sunfield Road' , '2211' , 'NSW' , 'Australia' , 9);]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# (psycopg2.errors.SyntaxError) ОШИБКА:  ошибка синтаксиса (примерное положение: "Duggan")
# LINE 1: INSERT INTO customers VALUES (440, 'Sheena' , 'O' Duggan', '...
#                                                           ^
#
# [SQL: INSERT INTO customers VALUES (440, 'Sheena' , 'O' Duggan', 'Female' , '1977-12-16' , 'Business Systems Development Analyst' , 'Telecommunications' , 'Mass Customer' , 'N)' , 'No' , '421 Bobwhite Road' , '2160' , 'NSW' , 'Australia' , 6);]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# (psycopg2.errors.SyntaxError) ОШИБКА:  ошибка синтаксиса (примерное положение: "Shirine")
# LINE 1: INSERT INTO customers VALUES (473, 'Benji' , 'O' Shirine', '...
#                                                          ^
#
# [SQL: INSERT INTO customers VALUES (473, 'Benji' , 'O' Shirine', 'Male' , '1977-03-13' , 'Junior Executive' , 'Health' , 'Mass Customer' , 'N)' , 'Yes' , '6674 Russell Center' , '2197' , 'NSW' , 'Australia' , 9);]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# (psycopg2.errors.SyntaxError) ОШИБКА:  ошибка синтаксиса (примерное положение: "Leahy")
# LINE 1: INSERT INTO customers VALUES (567, 'Hashim' , 'O' Leahy', 'M...
#                                                           ^
#
# [SQL: INSERT INTO customers VALUES (567, 'Hashim' , 'O' Leahy', 'Male' , '1965-07-08' , '' , 'Financial Services' , 'Affluent Customer' , 'N)' , 'No' , '37 Ilene Hill' , '3121' , 'Victoria' , 'Australia' , 10);]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# (psycopg2.errors.SyntaxError) ОШИБКА:  ошибка синтаксиса (примерное положение: "Hallagan")
# LINE 1: ...SERT INTO customers VALUES (613, 'Carolann' , 'O' Hallagan',...
#                                                              ^
#
# [SQL: INSERT INTO customers VALUES (613, 'Carolann' , 'O' Hallagan', 'Female' , '1989-11-14' , 'Analyst Programmer' , 'Property' , 'High Net Worth' , 'N)' , 'No' , '9 Schmedeman Hill' , '4075' , 'QLD' , 'Australia' , 7);]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# (psycopg2.errors.SyntaxError) ОШИБКА:  ошибка синтаксиса (примерное положение: "arcy")
# LINE 1: INSERT INTO customers VALUES (630, 'D' arcy', 'Rowden' , 'Ma...
#                                                ^
#
# [SQL: INSERT INTO customers VALUES (630, 'D' arcy', 'Rowden' , 'Male' , '1986-08-11' , 'Statistician III' , 'Property' , 'Affluent Customer' , 'N)' , 'Yes' , '04 Namekagon Pass' , '2326' , 'NSW' , 'Australia' , 3);]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# (psycopg2.errors.SyntaxError) ОШИБКА:  ошибка синтаксиса (примерное положение: "Hegertie")
# LINE 1: INSERT INTO customers VALUES (632, 'Angeli' , 'O' Hegertie',...
#                                                           ^
#
# [SQL: INSERT INTO customers VALUES (632, 'Angeli' , 'O' Hegertie', 'Male' , '1998-04-26' , 'General Manager' , 'Health' , 'Mass Customer' , 'N)' , 'No' , '8 Golf Drive' , '2747' , 'NSW' , 'Australia' , 9);]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# (psycopg2.errors.SyntaxError) ОШИБКА:  ошибка синтаксиса (примерное положение: "Keenan")
# LINE 1: INSERT INTO customers VALUES (640, 'Galvin' , 'O' Keenan', '...
#                                                           ^
#
# [SQL: INSERT INTO customers VALUES (640, 'Galvin' , 'O' Keenan', 'Male' , '1975-07-12' , 'Librarian' , 'Entertainment' , 'High Net Worth' , 'N)' , 'Yes' , '598 Randy Way' , '2380' , 'NSW' , 'Australia' , 1);]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
# ...
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# (psycopg2.errors.SyntaxError) ОШИБКА:  ошибка синтаксиса (примерное положение: "Kinedy")
# LINE 1: ...SERT INTO customers VALUES (3982, 'Maurita' , 'O' Kinedy', '...
#                                                              ^
#
# [SQL: INSERT INTO customers VALUES (3982, 'Maurita' , 'O' Kinedy', 'Female' , '1962-06-02' , 'General Manager' , 'Manufacturing' , 'Mass Customer' , 'N)' , 'Yes' , '614 Burning Wood Way' , '2148' , 'NSW' , 'Australia' , 9);]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.

# %%
for it, rows in transaction_table.iterrows():
    # %sql INSERT INTO transactions VALUES ({rows["transaction_id"]},    \
                                          {rows["product_id"]},        \
                                          {rows["customer_id"]},       \
                                         '{rows["transaction_date"]}', \
                                         '{rows["online_order"]}',     \
                                         '{rows["order_status"]}',     \
                                         '{rows["brand"]}',            \
                                         '{rows["product_line"]}',     \
                                         '{rows["product_class"]}',    \
                                         '{rows["product_size"]}',     \
                                          {rows["list_price"]},        \
                                          {rows["standard_cost"]});
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# (psycopg2.errors.ForeignKeyViolation) ОШИБКА:  INSERT или UPDATE в таблице "transactions" нарушает ограничение внешнего ключа "transactions_customer_id_fkey"
# DETAIL:  Ключ (customer_id)=(3120) отсутствует в таблице "customers".
#
# [SQL: INSERT INTO transactions VALUES (2, 3, 3120, '21.05.2017' , 'True' , 'Approved' , 'Trek Bicycles' , 'Standard' , 'medium' , 'large' , 2091.47, 388.92);]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# (psycopg2.errors.ForeignKeyViolation) ОШИБКА:  INSERT или UPDATE в таблице "transactions" нарушает ограничение внешнего ключа "transactions_customer_id_fkey"
# DETAIL:  Ключ (customer_id)=(3262) отсутствует в таблице "customers".
#
# [SQL: INSERT INTO transactions VALUES (10, 12, 3262, '30.08.2017' , 'True' , 'Approved' , 'WeareA2B' , 'Standard' , 'medium' , 'medium' , 1231.15, 161.60);]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# (psycopg2.errors.SyntaxError) ОШИБКА:  ошибка синтаксиса (примерное положение: ")")
# LINE 1: ...17' , 'False' , 'Approved' , '' , '' , '' , '' , 1942.61, );
#                                                                      ^
#
# [SQL: INSERT INTO transactions VALUES (137, 0, 431, '23.09.2017' , 'False' , 'Approved' , '' , '' , '' , '' , 1942.61, );]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# (psycopg2.errors.ForeignKeyViolation) ОШИБКА:  INSERT или UPDATE в таблице "transactions" нарушает ограничение внешнего ключа "transactions_customer_id_fkey"
# DETAIL:  Ключ (customer_id)=(3262) отсутствует в таблице "customers".
#
# [SQL: INSERT INTO transactions VALUES (148, 14, 3262, '13.01.2017' , 'False' , 'Approved' , 'Trek Bicycles' , 'Standard' , 'medium' , 'small' , 1386.84, 1234.29);]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# (psycopg2.errors.SyntaxError) ОШИБКА:  ошибка синтаксиса (примерное положение: ")")
# LINE 1: ...17' , 'False' , 'Approved' , '' , '' , '' , '' , 1656.86, );
#                                                                      ^
#
# [SQL: INSERT INTO transactions VALUES (160, 0, 3300, '27.08.2017' , 'False' , 'Approved' , '' , '' , '' , '' , 1656.86, );]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# (psycopg2.errors.ForeignKeyViolation) ОШИБКА:  INSERT или UPDATE в таблице "transactions" нарушает ограничение внешнего ключа "transactions_customer_id_fkey"
# DETAIL:  Ключ (customer_id)=(3262) отсутствует в таблице "customers".
#
# [SQL: INSERT INTO transactions VALUES (166, 78, 3262, '27.11.2017' , 'False' , 'Approved' , 'Giant Bicycles' , 'Standard' , 'medium' , 'large' , 1765.3, 709.48);]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# (psycopg2.errors.ForeignKeyViolation) ОШИБКА:  INSERT или UPDATE в таблице "transactions" нарушает ограничение внешнего ключа "transactions_customer_id_fkey"
# DETAIL:  Ключ (customer_id)=(3208) отсутствует в таблице "customers".
#
# [SQL: INSERT INTO transactions VALUES (201, 0, 3208, '05.09.2017' , 'True' , 'Approved' , 'Trek Bicycles' , 'Road' , 'medium' , 'medium' , 533.51, 400.13);]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# (psycopg2.errors.ForeignKeyViolation) ОШИБКА:  INSERT или UPDATE в таблице "transactions" нарушает ограничение внешнего ключа "transactions_customer_id_fkey"
# DETAIL:  Ключ (customer_id)=(1079) отсутствует в таблице "customers".
#
# [SQL: INSERT INTO transactions VALUES (294, 79, 1079, '25.08.2017' , 'True' , 'Approved' , 'Norco Bicycles' , 'Standard' , 'medium' , 'medium' , 1555.58, 818.01);]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# (psycopg2.errors.SyntaxError) ОШИБКА:  ошибка синтаксиса (примерное положение: ")")
# LINE 1: ...017' , 'False' , 'Approved' , '' , '' , '' , '' , 850.89, );
#                                                                      ^
#
# [SQL: INSERT INTO transactions VALUES (367, 0, 1614, '10.03.2017' , 'False' , 'Approved' , '' , '' , '' , '' , 850.89, );]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# (psycopg2.errors.SyntaxError) ОШИБКА:  ошибка синтаксиса (примерное положение: ")")
# LINE 1: ...2017' , 'True' , 'Approved' , '' , '' , '' , '' , 710.59, );
#                                                                      ^
#
# [SQL: INSERT INTO transactions VALUES (407, 0, 2559, '14.06.2017' , 'True' , 'Approved' , '' , '' , '' , '' , 710.59, );]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# (psycopg2.errors.ForeignKeyViolation) ОШИБКА:  INSERT или UPDATE в таблице "transactions" нарушает ограничение внешнего ключа "transactions_customer_id_fkey"
# DETAIL:  Ключ (customer_id)=(1841) отсутствует в таблице "customers".
#
# [SQL: INSERT INTO transactions VALUES (644, 97, 1841, '20.08.2017' , 'False' , 'Approved' , 'Solex' , 'Standard' , 'medium' , 'large' , 202.62, 151.96);]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
# ...
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# (psycopg2.errors.SyntaxError) ОШИБКА:  ошибка синтаксиса (примерное положение: ")")
# LINE 1: ...017' , 'False' , 'Approved' , '' , '' , '' , '' , 868.56, );
#                                                                      ^
#
# [SQL: INSERT INTO transactions VALUES (19794, 0, 2860, '13.01.2017' , 'False' , 'Approved' , '' , '' , '' , '' , 868.56, );]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# (psycopg2.errors.ForeignKeyViolation) ОШИБКА:  INSERT или UPDATE в таблице "transactions" нарушает ограничение внешнего ключа "transactions_customer_id_fkey"
# DETAIL:  Ключ (customer_id)=(3439) отсутствует в таблице "customers".
#
# [SQL: INSERT INTO transactions VALUES (19834, 95, 3439, '17.10.2017' , 'False' , 'Approved' , 'Giant Bicycles' , 'Standard' , 'medium' , 'large' , 569.56, 528.43);]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# (psycopg2.errors.SyntaxError) ОШИБКА:  ошибка синтаксиса (примерное положение: ")")
# LINE 1: ...017' , 'True' , 'Approved' , '' , '' , '' , '' , 1497.43, );
#                                                                      ^
#
# [SQL: INSERT INTO transactions VALUES (19860, 0, 2468, '24.06.2017' , 'True' , 'Approved' , '' , '' , '' , '' , 1497.43, );]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# (psycopg2.errors.SyntaxError) ОШИБКА:  ошибка синтаксиса (примерное положение: ")")
# LINE 1: ...2017' , 'True' , 'Approved' , '' , '' , '' , '' , 867.92, );
#                                                                      ^
#
# [SQL: INSERT INTO transactions VALUES (19872, 0, 61, '17.03.2017' , 'True' , 'Approved' , '' , '' , '' , '' , 867.92, );]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# (psycopg2.errors.ForeignKeyViolation) ОШИБКА:  INSERT или UPDATE в таблице "transactions" нарушает ограничение внешнего ключа "transactions_customer_id_fkey"
# DETAIL:  Ключ (customer_id)=(1766) отсутствует в таблице "customers".
#
# [SQL: INSERT INTO transactions VALUES (19924, 61, 1766, '05.07.2017' , 'True' , 'Approved' , 'OHM Cycles' , 'Standard' , 'low' , 'medium' , 71.16, 56.93);]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.

# %%
### List of questions:
   # - (1 балл) Вывести все уникальные бренды, у которых стандартная стоимость выше 1500 долларов.
   # - (1 балл) Вывести все подтвержденные транзакции за период '2017-04-01' по '2017-04-09' включительно.
   # - (1 балл) Вывести все профессии у клиентов из сферы IT или Financial Services, которые начинаются с фразы 'Senior'.
   # - (1 балл) Вывести все бренды, которые закупают клиенты, работающие в сфере Financial Services
   # - (1 балл) Вывести 10 клиентов, которые оформили онлайн-заказ продукции из брендов 'Giant Bicycles', 'Norco Bicycles', 'Trek Bicycles'.
   # - (1 балл) Вывести всех клиентов, у которых нет транзакций.
   # - (2 балла) Вывести всех клиентов из IT, у которых транзакции с максимальной стандартной стоимостью.
   # - (2 балла) Вывести всех клиентов из сферы IT и Health, у которых есть подтвержденные транзакции за период '2017-07-07' по '2017-07-17'.

# %%
### Вывести все уникальные бренды, у которых стандартная стоимость выше 1500 долларов.

# 4 rows affected.

# %%
# %%sql
#
# select distinct trans.brand from transactions trans where trans.standard_cost > 1500
# Out:
#  * postgresql://postgres:***@localhost/postgres
#
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 6 rows affected.
# [('Senior Cost Accountant',),
#  ('Senior Developer',),
#  ('Senior Editor',),
#  ('Senior Financial Analyst',),
#  ('Senior Quality Engineer',),
#  ('Senior Sales Associate',)]

# %%
### Вывести все бренды, которые закупают клиенты, работающие в сфере Financial Services
# We will not consider brands with NULL value

# 6 rows affected.

# %%
# %%sql
#
# select distinct trans.brand from transactions trans
#     where trans.brand is not NULL and trans.customer_id in (
#         select custom.customer_id from customers custom
#             where custom.job_industry_category = 'Financial Services'
#     );
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 6 rows affected.
# [('OHM Cycles',),
#  ('Trek Bicycles',),
#  ('WeareA2B',),
#  ('Solex',),
#  ('Norco Bicycles',),
#  ('Giant Bicycles',)]

# %%
### Вывести 10 клиентов, которые оформили онлайн-заказ продукции из брендов 'Giant Bicycles', 'Norco Bicycles', 'Trek Bicycles'.

# 10 rows affected.

# %%
# %%sql
#
# select distinct trans.customer_id from transactions trans
#     where trans.online_order = 'True' and trans.brand in ('Giant Bicycles', 'Norco Bicycles', 'Trek Bicycles')
# limit 10;
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 10 rows affected.
# [(1489,),
#  (2335,),
#  (652,),
#  (273,),
#  (51,),
#  (2574,),
#  (951,),
#  (70,),
#  (350,),
#  (758,)]

# %%
### Вывести всех клиентов, у которых нет транзакций.

# 506 rows affected.

# %%
# %%sql
#
# select custom.customer_id from customers custom
#     left join transactions trans on custom.customer_id = trans.customer_id
# where trans.customer_id is null
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 506 rows affected.
# [(852,),
#  (869,),
#  (1373,),
#  (2074,),
#  (2660,),
#  (3229,),
#  (3236,),
#  (3501,),
#  (3502,),
#  (3503,),
#  (3504,),
#  (3505,),
#  (3506,),
#  (3507,),
#  (3508,),
#  (3509,),
#  (3510,),
#  (3511,),
#  (3512,),
#  (3513,),
#  (3514,),
#  (3515,),
#  (3516,),
#  (3517,),
#  (3518,),
#  (3519,),
#  (3520,),
#  (3521,),
#  (3522,),
#  (3523,),
#  (3524,),
#  (3525,),
#  (3526,),
#  (3527,),
#  (3528,),
#  (3529,),
#  (3530,),
#  (3531,),
#  (3532,),
#  (3533,),
#  (3586,),
#  (3534,),
#  (3535,),
#  (3536,),
#  (3537,),
#  (3538,),
#  (3539,),
#  (3540,),
#  (3541,),
#  (3542,),
#  (3543,),
#  (3544,),
#  (3545,),
#  (3546,),
#  (3547,),
#  (3548,),
#  (3549,),
#  (3550,),
#  (3551,),
#  (3552,),
#  (3553,),
#  (3554,),
#  (3555,),
#  (3556,),
#  (3557,),
#  (3558,),
#  (3559,),
#  (3560,),
#  (3561,),
#  (3562,),
#  (3563,),
#  (3564,),
#  (3565,),
#  (3566,),
#  (3567,),
#  (3568,),
#  (3569,),
#  (3570,),
#  (3571,),
#  (3572,),
#  (3573,),
#  (3574,),
#  (3575,),
#  (3576,),
#  (3577,),
#  (3578,),
#  (3579,),
#  (3580,),
#  (3581,),
#  (3582,),
#  (3583,),
#  (3584,),
#  (3585,),
#  (3587,),
#  (3588,),
#  (3589,),
#  (3590,),
#  (3591,),
#  (3592,),
#  (3593,),
#  (3594,),
#  (3595,),
#  (3596,),
#  (3597,),
#  (3598,),
#  (3599,),
#  (3600,),
#  (3601,),
#  (3602,),
#  (3985,),
#  (3986,),
#  (3987,),
#  (3988,),
#  (3989,),
#  (3990,),
#  (3991,),
#  (3992,),
#  (3993,),
#  (3994,),
#  (3995,),
#  (3996,),
#  (3997,),
#  (3998,),
#  (3999,),
#  (4000,)]

# %%
### Вывести всех клиентов из IT, у которых транзакции с максимальной стандартной стоимостью.

# 9 rows affected.

# %%
# %%sql
#
# select distinct custom.customer_id from customers custom
# full outer join transactions trans on (custom.customer_id = trans.customer_id)
#     where custom.job_industry_category = 'IT' and trans.standard_cost = (
#         select max(trans.standard_cost) from transactions trans
# );
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 9 rows affected.
# [(34,), (893,), (975,), (1672,), (1773,), (1918,), (2913,), (3151,), (3473,)]

# %%
### Вывести всех клиентов из сферы IT и Health, у которых есть подтвержденные транзакции за период '2017-07-07' по '2017-07-17'.

# 112 rows affected.

# %%
# %%sql
#
# select distinct custom.customer_id from customers custom
# full outer join transactions trans on (custom.customer_id = trans.customer_id)
# where custom.job_industry_category in ('IT', 'Health') and  trans.transaction_id in (
#     select trans.transaction_id from transactions trans
#     where trans.order_status = 'Approved'
#         and to_date(trans.transaction_date, 'DD/MM/YYYY') <= '2017-07-17'
#         and to_date(trans.transaction_date, 'DD/MM/YYYY') >= '2017-07-07'
# );
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 112 rows affected.
# [(22,),
#  (28,),
#  (41,),
#  (47,),
#  (104,),
#  (235,),
#  (239,),
#  (290,),
#  (300,),
#  (320,),
#  (331,),
#  (338,),
#  (350,),
#  (382,),
#  (414,),
#  (424,),
#  (428,),
#  (503,),
#  (526,),
#  (579,),
#  (590,),
#  (612,),
#  (661,),
#  (679,),
#  (682,),
#  (685,),
#  (694,),
#  (708,),
#  (712,),
#  (722,),
#  (753,),
#  (759,),
#  (769,),
#  (779,),
#  (788,),
#  (872,),
#  (886,),
#  (892,),
#  (893,),
#  (936,),
#  (949,),
#  (950,),
#  (973,),
#  (1005,),
#  (1044,),
#  (1076,),
#  (1091,),
#  (1095,),
#  (1166,),
#  (1174,),
#  (1189,),
#  (1231,),
#  (1237,),
#  (1328,),
#  (1337,),
#  (1343,),
#  (1376,),
#  (1394,),
#  (1489,),
#  (1516,),
#  (1538,),
#  (1542,),
#  (1555,),
#  (1578,),
#  (1585,),
#  (1683,),
#  (1693,),
#  (1760,),
#  (1836,),
#  (1862,),
#  (1907,),
#  (1929,),
#  (1952,),
#  (1956,),
#  (2000,),
#  (2024,),
#  (2205,),
#  (2210,),
#  (2235,),
#  (2285,),
#  (2317,),
#  (2337,),
#  (2341,),
#  (2366,),
#  (2391,),
#  (2442,),
#  (2463,),
#  (2490,),
#  (2516,),
#  (2610,),
#  (2684,),
#  (2690,),
#  (2701,),
#  (2717,),
#  (2782,),
#  (2881,),
#  (2953,),
#  (2973,),
#  (3070,),
#  (3105,),
#  (3109,),
#  (3151,),
#  (3166,),
#  (3169,),
#  (3173,),
#  (3211,),
#  (3225,),
#  (3255,),
#  (3288,),
#  (3360,),
#  (3365,),
#  (3482,)]
